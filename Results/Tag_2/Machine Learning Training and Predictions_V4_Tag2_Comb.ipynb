# %% [markdown]
# # Model training and predictions
# ### Read from file and data cleaning

# %%
from pyspark.sql import SparkSession
spark  = SparkSession.builder.appName('App').config("spark.driver.memory", "14g").getOrCreate()

# %%
print(spark.sparkContext._conf.getAll())
# Out:
# [('spark.rdd.compress', 'True'), ('spark.app.name', 'App'), ('spark.serializer.objectStreamReset', '100'), ('spark.master', 'local[*]'), ('spark.submit.pyFiles', ''), ('spark.executor.id', 'driver'), ('spark.submit.deployMode', 'client'), ('spark.app.id', 'local-1607753514944'), ('spark.driver.port', '49773'), ('spark.driver.memory', '14g'), ('spark.driver.host', 'kailundembp.hitronhub.home'), ('spark.ui.showConsoleProgress', 'true')]

# %%
""" NOTE: If prepared data exists, load it here: 
"""

# test_df = spark.read.parquet("test_df")
# test_df = test_df.repartition(16)
# train_df = spark.read.parquet("train_df")
# train_df = train_df.repartition(16)
# Out:
# ' NOTE: If prepared data exists, load it here: \n'

# %%
# File location and type
file_location = "sample_comb2.csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","
multiline = "true"
escape = "\""

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.csv(file_location,
                  inferSchema = infer_schema, 
                  sep = delimiter, 
                  header = first_row_is_header, 
                  multiLine = multiline, 
                  escape = escape)
df = df.repartition(16)

# %%
df.show()
# Out:
# +--------------------+--------------------+------------------+
# |                Body|               Title|               tag|
# +--------------------+--------------------+------------------+
# |<p>My code looks ...|Ambiguous Overloa...|            string|
# |<p>I'm getting</p...|Entity framework ...|entity-framework-4|
# |<p>I disable a bu...|setEnabled Not wo...|       objective-c|
# |<p>i have just do...|Oxite Blog Engine...|     asp.net-mvc-2|
# |<p>Note - I have ...|Is the iPhone "cr...|              cron|
# |<p>I have an issu...|How to send a ses...|              ajax|
# |<p>Why are we usi...|Why are we using ...|             loops|
# |<p>Can any one sh...|   C# and PostgreSQL|              .net|
# |<p>I am building ...|A Binary choice b...|              .net|
# |<p>I know multipl...|How do I loop the...|       objective-c|
# |<p>The title sums...|How to build Goog...|     serialization|
# |<p>I am developin...|No file creation/...|              file|
# |<p>I want my face...|Is there a way to...|            iframe|
# |<p>I have a small...|How will the URL ...|       mod-rewrite|
# |<p>Eclipse is aut...|Eclipse is auto-c...|           eclipse|
# |<p>I am using asp...|Reliable Way to g...|           asp.net|
# |<p>I need to writ...|Print full call s...|           logging|
# |<p>So what I'm tr...|Getting My JavaSc...|        javascript|
# |<p>How can I chan...|how to change the...|            ubuntu|
# |<p>I think in the...|When deploying py...|         webserver|
# +--------------------+--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### Indexing tags in both test and train data sets

# %%
from pyspark.ml.feature import StringIndexer

#Encode tag's using String indexer

tag_idx = StringIndexer(inputCol='tag', outputCol = 'tag_idx')
tag_encode = tag_idx.fit(df)
df = tag_encode.transform(df)

# %%
df.count()
# Out:
# 99831

# %% [markdown]
# ### Split test/train sets

# %%
TRAINING_DATA_RATIO = 0.9
RANDOM_SEED = 1234

splits = [TRAINING_DATA_RATIO, 1.0 - TRAINING_DATA_RATIO]
training_data, test_data = df.randomSplit(splits, RANDOM_SEED)

# %%
print("Number of training set rows: %d" % training_data.count())
print("Number of test set rows: %d" % test_data.count())
# Out:
# Number of training set rows: 89911
# Number of test set rows: 9920

# %% [markdown]
# # Preprocessing

# %%
from bs4 import BeautifulSoup
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_en = stopwords.words('english')
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import RegexTokenizer

""" Helper functions for preprocessing. TODO: Consider wrapping into class below?
"""

@udf("String")
def lazy_prep_udf(c):
  """
  Clean noises from the string of text in given column

  Args:
    c - Column containing string of text

  Returns:
    Column with the cleaned string of text
  """
  df = BeautifulSoup(c)
  
  #noise
  urls = df.find_all('a')
  if urls != None:
    if len(urls)>0: 
      df.a.clear()
  
  return df.get_text().lower()

def tokenize(df, inputCol, outputCol):
  """
Split string of text in dataframe to word tokens.

Args:
  @param df Dataframe containing string of text
  @param inputCol name of input column containin the string of texts
  @param outputCol name of output column containin the word tokens
  
Returns:
  Dataframe containing the output column and the input column is dropped
"""
  tokenizer = RegexTokenizer(inputCol = inputCol, outputCol = outputCol, pattern=r"\s+") 
  df = tokenizer.transform(df).drop(inputCol)
  return df

def remove_punc(text):
  """Removes all punctuation marks from text.
  Args: 
    text (String): text column to convert 
  Returns:
    String.sql.Row: text w.o punctuation 
  """
  mod_punc = '!"$%&\'()*,-./:;<=>?@[\\]^_`{|}~'
  text = text.translate(str.maketrans(' ', ' ', mod_punc))
  return text.strip()


def remove_num(text):
  """Removes all numbers from text.
  Args: 
    text (String): text column to convert 
  Returns:
    String: text w.o numbers 
  """
  numbers="0123456789"
  text = text.translate(str.maketrans(' ', ' ', numbers))
  return text.strip()


  from nltk.tokenize import RegexpTokenizer 

@udf("String")
def trad_prep_udf(body):
  """Traditional body text preprocessing pieline. 
  Args: 
    text (pyspark.sql.Row): Text String to process
  Returns: 
    pyspark.sql.Row.ArrayType: cleaned tokens 
  """
  body = BeautifulSoup(body)
  stemmer = PorterStemmer()
  
  #noise
  urls = body.find_all('a')
  if len(urls)>0: 
    body.a.clear()
  
  text = body.get_text()
  
  words = []
  text = text.lower()

  tokenizer = RegexpTokenizer(r'\w+')
  # text = remove_punc(text)
  # text = remove_num(text)
  sents=tokenizer.tokenize(text)
  for sent in sents: 
    for word in nltk.word_tokenize(sent):
      if word in stop_en: continue
      # if len(word) < 3: continue
      words.append(stemmer.stem(word))
  return " ".join(words)


  """
Combine word tokens from title and body.

Args:
  df1 Dataframe containing Column with lists of stemmed word tokens from title
  inputCol1 name of the column containing lists of stemmed word tokens from title, cannot be same as inputCol2
  df2 Dataframe containing Column with lists of stemmed word tokens from body
  inputCol2 name of the column containing lists of stemmed word tokens from body, cannot be same as inputCol2
  outputCol column name of the ouput column containing the combined list of word tokens from title and body
"""
def combine_tokens(df, inputCol1, inputCol2, outputCol):
  result = df.withColumn(outputCol, concat(col(inputCol1), col(inputCol2)))
  return result
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kailunzhang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kailunzhang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
class Preprocessing:
  """Preprocessing stackoverflow question by remove html tags and tokenize words"""
  
  def __init__(self, df, titleCol, bodyCol):
    """
    Construct a Proprocessing object with attribute df: df cleans the text string in the given df using either lazy or traditional preprocessing
    """
    df = df.withColumn("Lazy_Title", lazy_prep_udf( df[titleCol] ) )
    df = df.withColumn("Lazy_Body", lazy_prep_udf( df[bodyCol] ) )
    df = df.withColumn("Trad_Title", trad_prep_udf( df[titleCol] ) )
    self.df = df.withColumn("Trad_Body", trad_prep_udf( df[bodyCol] ) )

  def get_token(self):
    self.df = tokenize(self.df, "Lazy_Title", 'Lazy_Title_Tokens')
    self.df = tokenize(self.df, "Lazy_Body", 'Lazy_Body_Tokens')
    self.df = tokenize(self.df, "Trad_Title", 'Trad_Title_Tokens')
    self.df = tokenize(self.df, "Trad_Body", 'Trad_Body_Tokens')
    return self.df

# %%
#Pre-processing the data
preProcessing = Preprocessing(df, "Title", "Body")
df_data = preProcessing.get_token()

# %%
from pyspark.sql.functions import desc, col

tag_counts = df.select('tag').groupby('tag').count().sort(desc('count'))
tag_counts.sort(col('count').desc()).show()
# Out:
# +--------------+-----+
# |           tag|count|
# +--------------+-----+
# |        jquery| 3911|
# |          .net| 2546|
# |         mysql| 2388|
# |       asp.net| 2021|
# |          html| 1905|
# |           css| 1765|
# |   objective-c| 1758|
# |           ios| 1691|
# |       android| 1466|
# |    javascript| 1153|
# |        arrays| 1139|
# |           sql| 1106|
# |         regex| 1075|
# |           xml|  991|
# |          ruby|  967|
# |    sql-server|  920|
# |           wpf|  801|
# |      database|  790|
# |multithreading|  767|
# |       windows|  762|
# +--------------+-----+
# only showing top 20 rows

# %%
body_counts = df_data.select('Trad_Body_Tokens').rdd.flatMap(lambda l : [(w,1) for w in l.Trad_Body_Tokens]).reduceByKey(lambda a,b: a+b).collect()
body_counts.sort(key=lambda tup: -tup[1])

# %%
display(body_counts[:10])
# Out:
# [('0', 99584),
#  ('use', 96038),
#  ('1', 93425),
#  ('new', 56676),
#  ('get', 55132),
#  ('class', 54582),
#  ('file', 53863),
#  ('id', 52945),
#  ('name', 50970),
#  ('2', 49484)]

# %%
title_counts = df_data.select('Trad_Title_Tokens').rdd.flatMap(lambda l : [(w,1) for w in l.Trad_Title_Tokens]).reduceByKey(lambda a,b: a+b).collect()
title_counts.sort(key=lambda tup: -tup[1])

# %%
display(title_counts[:10])
# Out:
# [('use', 9969),
#  ('file', 5649),
#  ('c', 5208),
#  ('get', 4318),
#  ('jqueri', 4240),
#  ('php', 4086),
#  ('error', 3427),
#  ('net', 3378),
#  ('data', 3318),
#  ('android', 3201)]

# %%
#Pre-processing the data
preProcessing = Preprocessing(test_data, "Title", "Body")
test_data = preProcessing.get_token()
preProcessing = Preprocessing(training_data, "Title", "Body")
training_data = preProcessing.get_token()

# %% [markdown]
# # Machine Learning Data Preparation

# %% [markdown]
# ### Feature Engineering

# %%
from pyspark.ml.feature import CountVectorizer, IDF, NGram, VectorAssembler, StringIndexer, HashingTF
from pyspark.ml import Pipeline
def feature_engineer():
# FOR LAZY PRE-PROCESSING
  lazy_body_vector = CountVectorizer(inputCol = 'Lazy_Body_Tokens', outputCol = 'lazy_body_vector', minDF=0.01 , maxDF=0.85)
  lazy_title_vector = CountVectorizer(inputCol = 'Lazy_Title_Tokens', outputCol = 'lazy_title_vector', minDF=0.01 , maxDF=0.85)
  # FOR TRAD PRE-PROCESSING
  trad_body_vector = CountVectorizer(inputCol = 'Trad_Body_Tokens', outputCol = 'trad_body_vector', minDF=0.01 , maxDF=0.99)
  trad_title_vector = CountVectorizer(inputCol = 'Trad_Title_Tokens', outputCol = 'trad_title_vector', minDF=0.01 , maxDF=0.99)

  lazy_features = VectorAssembler(inputCols=['lazy_body_vector', 'lazy_title_vector'], outputCol='lazy_features')
  trad_features = VectorAssembler(inputCols=['trad_body_vector', 'trad_title_vector'], outputCol='trad_features')
  pipe = Pipeline(stages=[lazy_body_vector, lazy_title_vector, lazy_features, trad_body_vector, trad_title_vector, trad_features])
  pipe_model = pipe.fit(training_data)
  train_df = pipe_model.transform(training_data)  
  test_df = pipe_model.transform(test_data)
  return train_df, test_df

# %%
train_df, test_df = feature_engineer()

# %%
test_df.select("Trad_Body_Tokens", "trad_features", 'Body').show()
# Out:
# +--------------------+--------------------+--------------------+
# |    Trad_Body_Tokens|       trad_features|                Body|
# +--------------------+--------------------+--------------------+
# |[possibl, duplic,...|(999,[1,3,12,14,2...|<blockquote>
#   <p...|
# |[possibl, duplic,...|(999,[1,14,26,30,...|<blockquote>
#   <p...|
# |[possibl, duplic,...|(999,[4,6,85,106,...|<blockquote>
#   <p...|
# |[pars, error, syn...|(999,[5,7,8,11,17...|<blockquote>
#   <p...|
# |[abstract, write,...|(999,[1,4,10,13,1...|<h3>Abstract</h3>...|
# |[sum_, n, 1, inft...|(999,[0,1,2,42,43...|<p>$$\sum_{n=1}^\...|
# |[1, see, panelgri...|(999,[2,5,9,13,20...|<p>1) I can see t...|
# |[seem, work, norm...|(999,[1,10,14,15,...|<p><a href="http:...|
# |[situat, insid, d...|(999,[0,1,3,14,20...|<p><a href="http:...|
# |[mention, includ,...|(999,[31,65,70,76...|<p><a href="http:...|
# |[io, app, contain...|(999,[0,4,7,9,10,...|<p><br>
# My iOS ap...|
# |[see, imag, attac...|(999,[1,15,20,28,...|<p><img src="http...|
# |[descript, 2, sys...|(999,[1,9,34,43,4...|<p><strong>Descri...|
# |[ajax, call, cons...|(999,[1,2,9,17,29...|<p><strong>From  ...|
# |[updat, 5, 10, 20...|(999,[0,1,2,4,6,9...|<p><strong>UPDATE...|
# |[imag, pie, chart...|(999,[10,11,14,16...|<p><strong>What I...|
# |[purpos, question...|(999,[14,20,34,59...|<p><strong>the pu...|
# |[window, form, ap...|(999,[6,11,18,27,...|<p>A Windows Form...|
# |[process, system,...|(999,[1,4,6,8,13,...|<p>A process in o...|
# |[remot, linux, we...|(999,[36,92,101,2...|<p>A remote linux...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Metrics helper

# %%
from pyspark.mllib.evaluation import MulticlassMetrics


def print_metrics(results_df, by_tag = False, ground_truth_col='tag_idx', prediction_col='prediction'):
    labels_and_predictions = results_df.select([ground_truth_col, prediction_col])
    # Instantiate metrics object
    metrics = MulticlassMetrics(labels_and_predictions.rdd)
    # Overall statistics
    precision = metrics.precision(1.0)
    recall = metrics.recall(1.0)
    f1Score = metrics.fMeasure(1.0)
    print("Summary Stats")
    print("Precision = %s" % precision)
    print("Recall = %s" % recall)
    print("F1 Score = %s" % f1Score)
    # Weighted stats
    print("Weighted recall = %s" % metrics.weightedRecall)
    print("Weighted precision = %s" % metrics.weightedPrecision)
    print("Weighted F(1) Score = %s" % metrics.weightedFMeasure())
    print("Weighted F(0.5) Score = %s" % metrics.weightedFMeasure(beta=0.5))
    print("Weighted false positive rate = %s" % metrics.weightedFalsePositiveRate)

    if by_tag: 
        # Statistics by class
        labels = df.rdd.map(lambda lp: lp.tag_idx).distinct().collect()
        # print(labels)
        for label in sorted(labels):
            try:
                print("Class %s precision = %s" % (label, metrics.precision(label)))
                print("Class %s recall = %s" % (label, metrics.recall(label)))
                print("Class %s F1 Measure = %s" % (label, metrics.fMeasure(label, beta=1.0)))
            except: 
                print("Class %s not in this set!" % (label))

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# **Hyperparameter Tuning**

# %%
from pyspark.ml.tuning import TrainValidationSplit, ParamGridBuilder
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import IndexToString


lr = LogisticRegression(featuresCol = "trad_features", labelCol = "tag_idx")

paramGrid = ParamGridBuilder()\
    .addGrid(lr.regParam, [0, 0.1, 1.0]) \
    .addGrid(lr.fitIntercept, [False, True])\
    .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0])\
    .build()

lr_tvs = TrainValidationSplit(estimator=lr, 
                          estimatorParamMaps=paramGrid,
                          evaluator = MulticlassClassificationEvaluator(labelCol='tag_idx'), 
                          trainRatio=0.9, 
                          seed=0
                         )

lr_grid_search = lr_tvs.fit(train_df)

# %%
print('Best Param (regParam): ', lr_grid_search.bestModel._java_obj.getRegParam())
print('Best Param (elasticNetParam): ', lr_grid_search.bestModel._java_obj.getElasticNetParam())
print('Best Param (fitIntercept): ', lr_grid_search.bestModel._java_obj.getFitIntercept())
# Out:
# Best Param (regParam):  0.0
# Best Param (elasticNetParam):  0.0
# Best Param (fitIntercept):  True

# %% [markdown]
# **Model training and transformation of test set**

# %%
from pyspark.ml.classification import LogisticRegression
# Lazy model
# lr_lazy = LogisticRegression(featuresCol = "lazy_features", labelCol = "tag_idx", fitIntercept=False, elasticNetParam=0, regParam=0.01)
# lr_lazy_model = lr_lazy.fit(train_df)
# lr_lazy_results = lr_lazy_model.transform(test_df)

# %%
from pyspark.ml.classification import LogisticRegression
# Trad model
lr_trad = LogisticRegression(featuresCol = "trad_features", labelCol = "tag_idx", fitIntercept=True, elasticNetParam=0.0, regParam=0.0)
lr_trad_model = lr_trad.fit(train_df)
lr_trad_results = lr_trad_model.transform(test_df)

# %% [markdown]
# **Performance Metrics**

# %%
# Trad Metrics
#lr_trad = LogisticRegression(featuresCol = "trad_features", labelCol = "tag_idx", fitIntercept=False, elasticNetParam=0.0, regParam=0)
print_metrics(lr_trad_results)
# Out:
# Summary Stats
# Precision = 0.09954751131221719
# Recall = 0.09649122807017543
# F1 Score = 0.09799554565701557
# Weighted recall = 0.18538306451612915
# Weighted precision = 0.19485865722594883
# Weighted F(1) Score = 0.18693310119681966
# Weighted F(0.5) Score = 0.19091495662009184
# Weighted false positive rate = 0.005670633008854041

# %%
# Trad Metrics
#lr_trad = LogisticRegression(featuresCol = "trad_features", labelCol = "tag_idx", fitIntercept=False, elasticNetParam=0.0, regParam=0.01)
#print_metrics(lr_trad_results)
# Out:
# Summary Stats
# Precision = 0.09954751131221719
# Recall = 0.09649122807017543
# F1 Score = 0.09799554565701557
# Weighted recall = 0.18538306451612915
# Weighted precision = 0.19485865722594883
# Weighted F(1) Score = 0.18693310119681966
# Weighted F(0.5) Score = 0.19091495662009184
# Weighted false positive rate = 0.005670633008854041

# %% [markdown]
# ##Random Forest

# %% [markdown]
# **Model training and transformation of test set**

# %%
from pyspark.ml.classification import RandomForestClassifier
# Trad Model
# TODO: Select best hyper parameters
rf_trad = RandomForestClassifier(featuresCol = "trad_features", labelCol = "tag_idx", maxDepth=15, numTrees=15)
rf_trad_model = rf_trad.fit(train_df)
rf_trad_result = rf_trad_model.transform(test_df)

# %% [markdown]
# **Performance Metrics**

# %%
# Trad Metrics 15 x 15
from pyspark.mllib.evaluation import MulticlassMetrics

#Get labels/predictions in RDD expected by metrics classes
rf_trad_labels_and_predictions = rf_trad_result.select(["tag_idx", "prediction"])

# Instantiate metrics object
rf_trad_metrics = MulticlassMetrics(rf_trad_labels_and_predictions.rdd)

# Weighted stats
print("Weighted recall = %s" % rf_trad_metrics.weightedRecall)
print("Weighted precision = %s" % rf_trad_metrics.weightedPrecision)
print("Weighted F(1) Score = %s" % rf_trad_metrics.weightedFMeasure())
print("Weighted F(0.5) Score = %s" % rf_trad_metrics.weightedFMeasure(beta=0.5))
print("Weighted false positive rate = %s" % rf_trad_metrics.weightedFalsePositiveRate)
# Out:
# Weighted recall = 0.18639112903225805
# Weighted precision = 0.598517786217488
# Weighted F(1) Score = 0.24704593349782364
# Weighted F(0.5) Score = 0.339775643932226
# Weighted false positive rate = 0.00862824210063521

# %% [markdown]
# # Results Analysis
# As we can see from the above, the __ and __ model performed best on the lazy features and traditional features, respectively. We will now use the __ model to determine the highest performing and lowest performing classes.

# %%
# TODO: Update with best performing model 
top_df = rf_trad_result
top_df.show()
# Out:
# +--------------------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |                Body|               Title|                 tag|tag_idx|   Lazy_Title_Tokens|    Lazy_Body_Tokens|   Trad_Title_Tokens|    Trad_Body_Tokens|    lazy_body_vector|   lazy_title_vector|       lazy_features|    trad_body_vector|   trad_title_vector|       trad_features|       rawPrediction|         probability|prediction|
# +--------------------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |<blockquote>
#   <p...|what is the diffe...|              string|   22.0|[what, is, the, d...|[possible, duplic...|[differ, use, str...|[possibl, duplic,...|(949,[1,2,6,7,24,...|(104,[4,11,13,33,...|(1053,[1,2,6,7,24...|(898,[1,3,12,14,2...|(101,[0,21,49],[1...|(999,[1,3,12,14,2...|[0.20873749869863...|[0.01391583324657...|      22.0|
# |<blockquote>
#   <p...|trying to POST wi...|                post|  299.0|[trying, to, post...|[possible, duplic...|[tri, post, pytho...|[possibl, duplic,...|(949,[0,3,4,9,10,...|(104,[0,5,70],[1....|(1053,[0,3,4,9,10...|(898,[1,14,26,30,...|    (101,[40],[1.0])|(999,[1,14,26,30,...|[0.71759425011148...|[0.04783961667409...|      20.0|
# |<blockquote>
#   <p...|How do I install ...|        installation|  257.0|[how, do, i, inst...|[possible, duplic...|[instal, color, s...|[possibl, duplic,...|(949,[0,5,8,10,13...|(104,[3,9,12,20],...|(1053,[0,5,8,10,1...|(898,[4,6,85,106,...|         (101,[],[])|(999,[4,6,85,106,...|[0.25814167291427...|[0.01720944486095...|       1.0|
# |<blockquote>
#   <p...|Parse error: synt...|             parsing|  127.0|[parse, error:, s...|[parse, error:, s...|[pars, error, syn...|[pars, error, syn...|(949,[1,2,4,6,7,1...|(104,[12,25],[1.0...|(1053,[1,2,4,6,7,...|(898,[5,7,8,11,17...|     (101,[6],[2.0])|(999,[5,7,8,11,17...|[1.53995286450799...|[0.10266352430053...|       5.0|
# |<h3>Abstract</h3>...|Get objects by va...|                .net|    1.0|[get, objects, by...|[abstract, i, am,...|[get, object, val...|[abstract, write,...|(949,[0,1,2,3,4,5...|(104,[6,23,41,46]...|(1053,[0,1,2,3,4,...|(898,[1,4,10,13,1...|(101,[3,10,15],[1...|(999,[1,4,10,13,1...|[0.25814167291427...|[0.01720944486095...|       1.0|
# |<p>$$\sum_{n=1}^\...|Convergence/Diver...|sequences-and-series|  427.0|[convergence/dive...|[$$\sum_{n=1}^\in...|[converg, diverg,...|[sum_, n, 1, inft...|(949,[0,2,3,5,10,...|    (104,[13],[1.0])|(1053,[0,2,3,5,10...|(898,[0,1,2,42,43...|     (101,[0],[1.0])|(999,[0,1,2,42,43...|[0.25814167291427...|[0.01720944486095...|       1.0|
# |<p>1) I can see t...|JSF 2 : panelGrid...|               jsf-2|  362.0|[jsf, 2, :, panel...|[1), i, can, see,...|[jsf, 2, panelgri...|[1, see, panelgri...|(949,[0,2,3,4,5,9...|         (104,[],[])|(1053,[0,2,3,4,5,...|(898,[2,5,9,13,20...|    (101,[51],[1.0])|(999,[2,5,9,13,20...|[0.66605320931535...|[0.04440354728769...|       5.0|
# |<p><a href="http:...|Strange IE bug on...|              jquery|    0.0|[strange, ie, bug...|[(this, seems, to...|[strang, ie, bug,...|[seem, work, norm...|(949,[0,2,3,4,5,8...|     (104,[8],[1.0])|(1053,[0,2,3,4,5,...|(898,[1,10,14,15,...|    (101,[65],[1.0])|(999,[1,10,14,15,...|[0.29945731154307...|[0.01996382076953...|       1.0|
# |<p><a href="http:...|Webkit opacity tr...|                 css|    5.0|[webkit, opacity,...|[the, situation, ...|[webkit, opac, tr...|[situat, insid, d...|(949,[0,2,3,4,5,8...|(104,[5,61],[1.0,...|(1053,[0,2,3,4,5,...|(898,[0,1,3,14,20...|(101,[43,64],[1.0...|(999,[0,1,3,14,20...|[1.26242195174035...|[0.08416146344935...|       0.0|
# |<p><a href="http:...|Navigation bars w...|                xaml|  112.0|[navigation, bars...|[does, mention, t...|[navig, bar, thum...|[mention, includ,...|(949,[0,4,9,11,12...|(104,[1,5,36],[1....|(1053,[0,4,9,11,1...|(898,[31,65,70,76...|    (101,[13],[1.0])|(999,[31,65,70,76...|[0.22255368928269...|[0.01483691261884...|       7.0|
# |<p><br>
# My iOS ap...|CFStream SSL erro...|         objective-c|    6.0|[cfstream, ssl, e...|[my, ios, app, co...|[cfstream, ssl, e...|[io, app, contain...|(949,[0,1,2,3,5,6...|    (104,[26],[1.0])|(1053,[0,1,2,3,5,...|(898,[0,4,7,9,10,...|     (101,[6],[1.0])|(999,[0,4,7,9,10,...|[0.17197802061449...|[0.01146520137429...|       6.0|
# |<p><img src="http...|Substitue for css...|                 css|    5.0|[substitue, for, ...|[as, you, can, se...|[substitu, css, u...|[see, imag, attac...|(949,[0,1,2,3,4,5...|     (104,[9],[1.0])|(1053,[0,1,2,3,4,...|(898,[1,15,20,28,...|    (101,[90],[1.0])|(999,[1,15,20,28,...|[0.66605569902895...|[0.04440371326859...|       5.0|
# |<p><strong>Descri...|Problem in access...|             windows|   19.0|[problem, in, acc...|[description, i, ...|[problem, access,...|[descript, 2, sys...|(949,[0,2,3,4,5,8...|(104,[1,8,13,36,1...|(1053,[0,2,3,4,5,...|(898,[1,9,34,43,4...|(101,[0,13,46,58]...|(999,[1,9,34,43,4...|[0.18009320011192...|[0.01200621334079...|      50.0|
# |<p><strong>From  ...|How to constructi...|              jquery|    0.0|[how, to, constru...|[from, ajax, call...|[construct, javas...|[ajax, call, cons...|(949,[0,1,2,4,8,9...|(104,[0,3,5,35,44...|(1053,[0,1,2,4,8,...|(898,[1,2,9,17,29...|(101,[17,23],[1.0...|(999,[1,2,9,17,29...|[1.84703714893935...|[0.12313580992929...|      10.0|
# |<p><strong>UPDATE...|Parsing Apache lo...|                perl|  101.0|[parsing, apache,...|[updated, 5-10-20...|[pars, apach, log...|[updat, 5, 10, 20...|(949,[0,1,2,3,5,6...|     (104,[1],[1.0])|(1053,[0,1,2,3,5,...|(898,[0,1,2,4,6,9...|         (101,[],[])|(999,[0,1,2,4,6,9...|[0.26611699655155...|[0.01774113310343...|      12.0|
# |<p><strong>What I...|Showing tooltip o...|                 css|    5.0|[showing, tooltip...|[what, i, have, i...|[show, tooltip, m...|[imag, pie, chart...|(949,[0,1,2,4,5,6...|(104,[8,49],[1.0,...|(1053,[0,1,2,4,5,...|(898,[10,11,14,16...|(101,[20,77],[1.0...|(999,[10,11,14,16...|[1.78467813944135...|[0.11897854262942...|       5.0|
# |<p><strong>the pu...|A comparison betw...|                .net|    1.0|[a, comparison, b...|[the, purpose, of...|[comparison, coco...|[purpos, question...|(949,[2,3,5,8,9,1...|(104,[2,4,7,92],[...|(1053,[2,3,5,8,9,...|(898,[14,20,34,59...|     (101,[7],[1.0])|(999,[14,20,34,59...|[0.23305601699264...|[0.01553706779950...|       1.0|
# |<p>A Windows Form...|VS2010: View .set...|  visual-studio-2010|   36.0|[vs2010:, view, ....|[a, windows, form...|[vs2010, view, se...|[window, form, ap...|(949,[0,2,4,5,22,...|(104,[19,90],[1.0...|(1053,[0,2,4,5,22...|(898,[6,11,18,27,...|(101,[1,29,52],[1...|(999,[6,11,18,27,...|[0.26970715126289...|[0.01798047675085...|       1.0|
# |<p>A process in o...|Designing databas...|            database|   17.0|[designing, datab...|[a, process, in, ...|[design, databas,...|[process, system,...|(949,[0,2,3,4,5,8...|(104,[6,17,38,50,...|(1053,[0,2,3,4,5,...|(898,[1,4,6,8,13,...|(101,[32,50,51],[...|(999,[1,4,6,8,13,...|[0.18587387353168...|[0.01239159156877...|      17.0|
# |<p>A remote linux...|What steps to tak...|             apache2|  223.0|[what, steps, to,...|[a, remote, linux...|[step, take, find...|[remot, linux, we...|(949,[0,3,38,64,7...|(104,[0,4,33,99,1...|(1053,[0,3,38,64,...|(898,[36,92,101,2...|(101,[58,69],[1.0...|(999,[36,92,101,2...|[0.19781945787747...|[0.01318796385849...|      24.0|
# +--------------------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
# write prepared file for further use
top_df.write.parquet("top_df1")

# %%
top_df = spark.read.parquet("top_df1")
top_df.cache()
top_df.select(["tag", "tag_idx", "prediction"]).show()

# %%
top_df.count()
# Out:
# 19839

# %%
top_df.select(["tag", "tag_idx", "prediction"]).show()
# Out:
# +------------------+-------+----------+
# |               tag|tag_idx|prediction|
# +------------------+-------+----------+
# |  active-directory|  219.0|     467.0|
# |            jquery|    0.0|      63.0|
# |       objective-c|    6.0|      13.0|
# |              ios6|  446.0|     478.0|
# |        coldfusion|  331.0|      65.0|
# |              .net|    1.0|       6.0|
# |        javascript|    9.0|     194.0|
# |             swing|   26.0|      79.0|
# |       objective-c|    6.0|       6.0|
# |visual-studio-2010|   36.0|     115.0|
# |            jquery|    0.0|      12.0|
# |               stl|  239.0|     216.0|
# |               sql|   11.0|       2.0|
# |       codeigniter|   89.0|       4.0|
# |  web-applications|  165.0|      60.0|
# |             forms|   43.0|     155.0|
# |     ruby-on-rails|   70.0|      11.0|
# |        batch-file|  379.0|     286.0|
# |           caching|  154.0|      44.0|
# |             swing|   26.0|      26.0|
# +------------------+-------+----------+
# only showing top 20 rows

# %%
from pyspark.mllib.evaluation import MulticlassMetrics


def print_metrics(results_df, ground_truth_col='tag_idx', prediction_col='prediction'):
    labels_and_predictions = results_df.select([ground_truth_col, prediction_col])
    # Instantiate metrics object
    metrics = MulticlassMetrics(labels_and_predictions.rdd)
    # Overall statistics
    precision = metrics.precision(1.0)
    recall = metrics.recall(1.0)
    f1Score = metrics.fMeasure(1.0)
    print("Summary Stats")
    print("Precision = %s" % precision)
    print("Recall = %s" % recall)
    print("F1 Score = %s" % f1Score)
    # Weighted stats
    print("Weighted recall = %s" % metrics.weightedRecall)
    print("Weighted precision = %s" % metrics.weightedPrecision)
    print("Weighted F(1) Score = %s" % metrics.weightedFMeasure())
    print("Weighted F(0.5) Score = %s" % metrics.weightedFMeasure(beta=0.5))
    print("Weighted false positive rate = %s" % metrics.weightedFalsePositiveRate)

    # Statistics by class
    labels = df.rdd.map(lambda lp: lp.tag_idx).distinct().collect()
    # print(labels)
    for label in sorted(labels):
        try:
            print("Class %s precision = %s" % (label, metrics.precision(label)))
            print("Class %s recall = %s" % (label, metrics.recall(label)))
            print("Class %s F1 Measure = %s" % (label, metrics.fMeasure(label, beta=1.0)))
        except: 
            print("Class %s not in this set!" % (label))

print_metrics(top_df)
# Out:
# Summary Stats
# Precision = 0.14845360824742268
# Recall = 0.16179775280898875
# F1 Score = 0.15483870967741933
# Weighted recall = 0.15640909320026256
# Weighted precision = 0.1632408887876371
# Weighted F(1) Score = 0.15755747756514918
# Weighted F(0.5) Score = 0.1603931706034268
# Weighted false positive rate = 0.0055929542867909
# Class 0.0 precision = 0.30617283950617286
# Class 0.0 recall = 0.35942028985507246
# Class 0.0 F1 Measure = 0.33066666666666666
# Class 1.0 precision = 0.14845360824742268
# Class 1.0 recall = 0.16179775280898875
# Class 1.0 F1 Measure = 0.15483870967741933
# Class 2.0 precision = 0.4294478527607362
# Class 2.0 recall = 0.4646017699115044
# Class 2.0 F1 Measure = 0.4463336875664187
# Class 3.0 precision = 0.20698254364089774
# Class 3.0 recall = 0.23314606741573032
# Class 3.0 F1 Measure = 0.2192866578599736
# Class 4.0 precision = 0.11282051282051282
# Class 4.0 recall = 0.18487394957983194
# Class 4.0 F1 Measure = 0.14012738853503187
# Class 5.0 precision = 0.45042492917847027
# Class 5.0 recall = 0.36384439359267734
# Class 5.0 F1 Measure = 0.4025316455696203
# Class 6.0 precision = 0.2734584450402145
# Class 6.0 recall = 0.2712765957446808
# Class 6.0 F1 Measure = 0.27236315086782376
# Class 7.0 precision = 0.19005847953216373
# Class 7.0 recall = 0.23809523809523808
# Class 7.0 F1 Measure = 0.2113821138211382
# Class 8.0 precision = 0.25435540069686413
# Class 8.0 recall = 0.23624595469255663
# Class 8.0 F1 Measure = 0.24496644295302017
# Class 9.0 precision = 0.1700404858299595
# Class 9.0 recall = 0.20689655172413793
# Class 9.0 F1 Measure = 0.18666666666666668
# Class 10.0 precision = 0.43162393162393164
# Class 10.0 recall = 0.4156378600823045
# Class 10.0 F1 Measure = 0.42348008385744235
# Class 11.0 precision = 0.12315270935960591
# Class 11.0 recall = 0.1358695652173913
# Class 11.0 F1 Measure = 0.12919896640826872
# Class 12.0 precision = 0.3981042654028436
# Class 12.0 recall = 0.3559322033898305
# Class 12.0 F1 Measure = 0.37583892617449666
# Class 13.0 precision = 0.37894736842105264
# Class 13.0 recall = 0.34615384615384615
# Class 13.0 F1 Measure = 0.36180904522613067
# Class 14.0 precision = 0.22162162162162163
# Class 14.0 recall = 0.23163841807909605
# Class 14.0 F1 Measure = 0.22651933701657456
# Class 15.0 precision = 0.23783783783783785
# Class 15.0 recall = 0.2222222222222222
# Class 15.0 F1 Measure = 0.22976501305483027
# Class 16.0 precision = 0.1390728476821192
# Class 16.0 recall = 0.13548387096774195
# Class 16.0 F1 Measure = 0.13725490196078433
# Class 17.0 precision = 0.09722222222222222
# Class 17.0 recall = 0.1044776119402985
# Class 17.0 F1 Measure = 0.10071942446043165
# Class 18.0 precision = 0.3522012578616352
# Class 18.0 recall = 0.3236994219653179
# Class 18.0 F1 Measure = 0.3373493975903615
# Class 19.0 precision = 0.16049382716049382
# Class 19.0 recall = 0.13756613756613756
# Class 19.0 F1 Measure = 0.14814814814814814
# Class 20.0 precision = 0.18518518518518517
# Class 20.0 recall = 0.1910828025477707
# Class 20.0 F1 Measure = 0.18808777429467086
# Class 21.0 precision = 0.16923076923076924
# Class 21.0 recall = 0.14965986394557823
# Class 21.0 F1 Measure = 0.1588447653429603
# Class 22.0 precision = 0.2706766917293233
# Class 22.0 recall = 0.25
# Class 22.0 F1 Measure = 0.259927797833935
# Class 23.0 precision = 0.15447154471544716
# Class 23.0 recall = 0.1450381679389313
# Class 23.0 F1 Measure = 0.14960629921259844
# Class 24.0 precision = 0.08943089430894309
# Class 24.0 recall = 0.07586206896551724
# Class 24.0 F1 Measure = 0.08208955223880597
# Class 25.0 precision = 0.04065040650406504
# Class 25.0 recall = 0.03875968992248062
# Class 25.0 F1 Measure = 0.03968253968253968
# Class 26.0 precision = 0.3819444444444444
# Class 26.0 recall = 0.34375
# Class 26.0 F1 Measure = 0.36184210526315785
# Class 27.0 precision = 0.11304347826086956
# Class 27.0 recall = 0.08609271523178808
# Class 27.0 F1 Measure = 0.09774436090225563
# Class 28.0 precision = 0.30578512396694213
# Class 28.0 recall = 0.26618705035971224
# Class 28.0 F1 Measure = 0.2846153846153846
# Class 29.0 precision = 0.25984251968503935
# Class 29.0 recall = 0.25384615384615383
# Class 29.0 F1 Measure = 0.25680933852140075
# Class 30.0 precision = 0.16153846153846155
# Class 30.0 recall = 0.19090909090909092
# Class 30.0 F1 Measure = 0.17500000000000002
# Class 31.0 precision = 0.17054263565891473
# Class 31.0 recall = 0.1746031746031746
# Class 31.0 F1 Measure = 0.17254901960784313
# Class 32.0 precision = 0.11702127659574468
# Class 32.0 recall = 0.10377358490566038
# Class 32.0 F1 Measure = 0.11
# Class 33.0 precision = 0.2604166666666667
# Class 33.0 recall = 0.2808988764044944
# Class 33.0 F1 Measure = 0.27027027027027023
# Class 34.0 precision = 0.1368421052631579
# Class 34.0 recall = 0.1262135922330097
# Class 34.0 F1 Measure = 0.1313131313131313
# Class 35.0 precision = 0.0989010989010989
# Class 35.0 recall = 0.09782608695652174
# Class 35.0 F1 Measure = 0.09836065573770492
# Class 36.0 precision = 0.08163265306122448
# Class 36.0 recall = 0.08333333333333333
# Class 36.0 F1 Measure = 0.08247422680412371
# Class 37.0 precision = 0.12048192771084337
# Class 37.0 recall = 0.09174311926605505
# Class 37.0 F1 Measure = 0.10416666666666667
# Class 38.0 precision = 0.15853658536585366
# Class 38.0 recall = 0.13131313131313133
# Class 38.0 F1 Measure = 0.14364640883977903
# Class 39.0 precision = 0.11702127659574468
# Class 39.0 recall = 0.12222222222222222
# Class 39.0 F1 Measure = 0.11956521739130434
# Class 40.0 precision = 0.07692307692307693
# Class 40.0 recall = 0.04950495049504951
# Class 40.0 F1 Measure = 0.06024096385542169
# Class 41.0 precision = 0.08536585365853659
# Class 41.0 recall = 0.09210526315789473
# Class 41.0 F1 Measure = 0.08860759493670886
# Class 42.0 precision = 0.16901408450704225
# Class 42.0 recall = 0.13333333333333333
# Class 42.0 F1 Measure = 0.14906832298136646
# Class 43.0 precision = 0.23684210526315788
# Class 43.0 recall = 0.17647058823529413
# Class 43.0 F1 Measure = 0.20224719101123598
# Class 44.0 precision = 0.11363636363636363
# Class 44.0 recall = 0.09615384615384616
# Class 44.0 F1 Measure = 0.10416666666666666
# Class 45.0 precision = 0.14444444444444443
# Class 45.0 recall = 0.14285714285714285
# Class 45.0 F1 Measure = 0.143646408839779
# Class 46.0 precision = 0.11688311688311688
# Class 46.0 recall = 0.09574468085106383
# Class 46.0 F1 Measure = 0.10526315789473682
# Class 47.0 precision = 0.1780821917808219
# Class 47.0 recall = 0.12149532710280374
# Class 47.0 F1 Measure = 0.14444444444444443
# Class 48.0 precision = 0.24691358024691357
# Class 48.0 recall = 0.20618556701030927
# Class 48.0 F1 Measure = 0.2247191011235955
# Class 49.0 precision = 0.1320754716981132
# Class 49.0 recall = 0.0945945945945946
# Class 49.0 F1 Measure = 0.11023622047244094
# Class 50.0 precision = 0.2
# Class 50.0 recall = 0.22058823529411764
# Class 50.0 F1 Measure = 0.2097902097902098
# Class 51.0 precision = 0.17543859649122806
# Class 51.0 recall = 0.09900990099009901
# Class 51.0 F1 Measure = 0.12658227848101267
# Class 52.0 precision = 0.05405405405405406
# Class 52.0 recall = 0.0425531914893617
# Class 52.0 F1 Measure = 0.047619047619047616
# Class 53.0 precision = 0.15492957746478872
# Class 53.0 recall = 0.1134020618556701
# Class 53.0 F1 Measure = 0.13095238095238096
# Class 54.0 precision = 0.1125
# Class 54.0 recall = 0.125
# Class 54.0 F1 Measure = 0.11842105263157895
# Class 55.0 precision = 0.21875
# Class 55.0 recall = 0.2
# Class 55.0 F1 Measure = 0.20895522388059704
# Class 56.0 precision = 0.16981132075471697
# Class 56.0 recall = 0.1232876712328767
# Class 56.0 F1 Measure = 0.14285714285714285
# Class 57.0 precision = 0.20689655172413793
# Class 57.0 recall = 0.15384615384615385
# Class 57.0 F1 Measure = 0.17647058823529413
# Class 58.0 precision = 0.05263157894736842
# Class 58.0 recall = 0.033707865168539325
# Class 58.0 F1 Measure = 0.0410958904109589
# Class 59.0 precision = 0.1527777777777778
# Class 59.0 recall = 0.125
# Class 59.0 F1 Measure = 0.1375
# Class 60.0 precision = 0.40350877192982454
# Class 60.0 recall = 0.2948717948717949
# Class 60.0 F1 Measure = 0.34074074074074073
# Class 61.0 precision = 0.15789473684210525
# Class 61.0 recall = 0.10714285714285714
# Class 61.0 F1 Measure = 0.1276595744680851
# Class 62.0 precision = 0.11290322580645161
# Class 62.0 recall = 0.07865168539325842
# Class 62.0 F1 Measure = 0.09271523178807947
# Class 63.0 precision = 0.16417910447761194
# Class 63.0 recall = 0.125
# Class 63.0 F1 Measure = 0.14193548387096772
# Class 64.0 precision = 0.1016949152542373
# Class 64.0 recall = 0.08450704225352113
# Class 64.0 F1 Measure = 0.09230769230769231
# Class 65.0 precision = 0.05263157894736842
# Class 65.0 recall = 0.036585365853658534
# Class 65.0 F1 Measure = 0.043165467625899276
# Class 66.0 precision = 0.05
# Class 66.0 recall = 0.034482758620689655
# Class 66.0 F1 Measure = 0.04081632653061224
# Class 67.0 precision = 0.08823529411764706
# Class 67.0 recall = 0.09836065573770492
# Class 67.0 F1 Measure = 0.09302325581395347
# Class 68.0 precision = 0.19298245614035087
# Class 68.0 recall = 0.13414634146341464
# Class 68.0 F1 Measure = 0.15827338129496404
# Class 69.0 precision = 0.25806451612903225
# Class 69.0 recall = 0.22857142857142856
# Class 69.0 F1 Measure = 0.24242424242424246
# Class 70.0 precision = 0.13513513513513514
# Class 70.0 recall = 0.16666666666666666
# Class 70.0 F1 Measure = 0.14925373134328357
# Class 71.0 precision = 0.27586206896551724
# Class 71.0 recall = 0.20253164556962025
# Class 71.0 F1 Measure = 0.23357664233576644
# Class 72.0 precision = 0.22807017543859648
# Class 72.0 recall = 0.20967741935483872
# Class 72.0 F1 Measure = 0.21848739495798322
# Class 73.0 precision = 0.24074074074074073
# Class 73.0 recall = 0.18840579710144928
# Class 73.0 F1 Measure = 0.2113821138211382
# Class 74.0 precision = 0.08620689655172414
# Class 74.0 recall = 0.08064516129032258
# Class 74.0 F1 Measure = 0.08333333333333334
# Class 75.0 precision = 0.14285714285714285
# Class 75.0 recall = 0.13333333333333333
# Class 75.0 F1 Measure = 0.1379310344827586
# Class 76.0 precision = 0.15217391304347827
# Class 76.0 recall = 0.07291666666666667
# Class 76.0 F1 Measure = 0.09859154929577464
# Class 77.0 precision = 0.03636363636363636
# Class 77.0 recall = 0.024096385542168676
# Class 77.0 F1 Measure = 0.028985507246376812
# Class 78.0 precision = 0.125
# Class 78.0 recall = 0.109375
# Class 78.0 F1 Measure = 0.11666666666666667
# Class 79.0 precision = 0.0
# Class 79.0 recall = 0.0
# Class 79.0 F1 Measure = 0.0
# Class 80.0 precision = 0.08888888888888889
# Class 80.0 recall = 0.056338028169014086
# Class 80.0 F1 Measure = 0.06896551724137932
# Class 81.0 precision = 0.16981132075471697
# Class 81.0 recall = 0.18
# Class 81.0 F1 Measure = 0.17475728155339804
# Class 82.0 precision = 0.08771929824561403
# Class 82.0 recall = 0.06944444444444445
# Class 82.0 F1 Measure = 0.07751937984496124
# Class 83.0 precision = 0.17543859649122806
# Class 83.0 recall = 0.23809523809523808
# Class 83.0 F1 Measure = 0.20202020202020202
# Class 84.0 precision = 0.11363636363636363
# Class 84.0 recall = 0.07246376811594203
# Class 84.0 F1 Measure = 0.08849557522123894
# Class 85.0 precision = 0.07407407407407407
# Class 85.0 recall = 0.0547945205479452
# Class 85.0 F1 Measure = 0.06299212598425197
# Class 86.0 precision = 0.043478260869565216
# Class 86.0 recall = 0.02531645569620253
# Class 86.0 F1 Measure = 0.032
# Class 87.0 precision = 0.10526315789473684
# Class 87.0 recall = 0.08955223880597014
# Class 87.0 F1 Measure = 0.0967741935483871
# Class 88.0 precision = 0.10344827586206896
# Class 88.0 recall = 0.0967741935483871
# Class 88.0 F1 Measure = 0.09999999999999999
# Class 89.0 precision = 0.16666666666666666
# Class 89.0 recall = 0.13636363636363635
# Class 89.0 F1 Measure = 0.15
# Class 90.0 precision = 0.13043478260869565
# Class 90.0 recall = 0.09523809523809523
# Class 90.0 F1 Measure = 0.11009174311926605
# Class 91.0 precision = 0.10638297872340426
# Class 91.0 recall = 0.078125
# Class 91.0 F1 Measure = 0.0900900900900901
# Class 92.0 precision = 0.02127659574468085
# Class 92.0 recall = 0.015625
# Class 92.0 F1 Measure = 0.018018018018018018
# Class 93.0 precision = 0.0
# Class 93.0 recall = 0.0
# Class 93.0 F1 Measure = 0.0
# Class 94.0 precision = 0.04
# Class 94.0 recall = 0.044444444444444446
# Class 94.0 F1 Measure = 0.042105263157894736
# Class 95.0 precision = 0.018867924528301886
# Class 95.0 recall = 0.016129032258064516
# Class 95.0 F1 Measure = 0.01739130434782609
# Class 96.0 precision = 0.28888888888888886
# Class 96.0 recall = 0.23636363636363636
# Class 96.0 F1 Measure = 0.26
# Class 97.0 precision = 0.2222222222222222
# Class 97.0 recall = 0.18181818181818182
# Class 97.0 F1 Measure = 0.19999999999999998
# Class 98.0 precision = 0.07142857142857142
# Class 98.0 recall = 0.05084745762711865
# Class 98.0 F1 Measure = 0.05940594059405941
# Class 99.0 precision = 0.42592592592592593
# Class 99.0 recall = 0.41818181818181815
# Class 99.0 F1 Measure = 0.42201834862385323
# Class 100.0 precision = 0.06666666666666667
# Class 100.0 recall = 0.05660377358490566
# Class 100.0 F1 Measure = 0.061224489795918366
# Class 101.0 precision = 0.09523809523809523
# Class 101.0 recall = 0.05555555555555555
# Class 101.0 F1 Measure = 0.07017543859649122
# Class 102.0 precision = 0.18181818181818182
# Class 102.0 recall = 0.1111111111111111
# Class 102.0 F1 Measure = 0.13793103448275862
# Class 103.0 precision = 0.07317073170731707
# Class 103.0 recall = 0.07317073170731707
# Class 103.0 F1 Measure = 0.07317073170731707
# Class 104.0 precision = 0.08333333333333333
# Class 104.0 recall = 0.04838709677419355
# Class 104.0 F1 Measure = 0.061224489795918366
# Class 105.0 precision = 0.0425531914893617
# Class 105.0 recall = 0.03571428571428571
# Class 105.0 F1 Measure = 0.038834951456310676
# Class 106.0 precision = 0.11363636363636363
# Class 106.0 recall = 0.08620689655172414
# Class 106.0 F1 Measure = 0.09803921568627451
# Class 107.0 precision = 0.24
# Class 107.0 recall = 0.21052631578947367
# Class 107.0 F1 Measure = 0.22429906542056072
# Class 108.0 precision = 0.19444444444444445
# Class 108.0 recall = 0.09333333333333334
# Class 108.0 F1 Measure = 0.12612612612612611
# Class 109.0 precision = 0.19148936170212766
# Class 109.0 recall = 0.21951219512195122
# Class 109.0 F1 Measure = 0.20454545454545456
# Class 110.0 precision = 0.08108108108108109
# Class 110.0 recall = 0.05454545454545454
# Class 110.0 F1 Measure = 0.06521739130434784
# Class 111.0 precision = 0.23529411764705882
# Class 111.0 recall = 0.16326530612244897
# Class 111.0 F1 Measure = 0.19277108433734938
# Class 112.0 precision = 0.09090909090909091
# Class 112.0 recall = 0.0975609756097561
# Class 112.0 F1 Measure = 0.09411764705882353
# Class 113.0 precision = 0.041666666666666664
# Class 113.0 recall = 0.04878048780487805
# Class 113.0 F1 Measure = 0.04494382022471909
# Class 114.0 precision = 0.16666666666666666
# Class 114.0 recall = 0.11764705882352941
# Class 114.0 F1 Measure = 0.13793103448275862
# Class 115.0 precision = 0.09523809523809523
# Class 115.0 recall = 0.06896551724137931
# Class 115.0 F1 Measure = 0.08
# Class 116.0 precision = 0.14
# Class 116.0 recall = 0.14285714285714285
# Class 116.0 F1 Measure = 0.1414141414141414
# Class 117.0 precision = 0.16666666666666666
# Class 117.0 recall = 0.21875
# Class 117.0 F1 Measure = 0.18918918918918917
# Class 118.0 precision = 0.10204081632653061
# Class 118.0 recall = 0.09433962264150944
# Class 118.0 F1 Measure = 0.09803921568627452
# Class 119.0 precision = 0.0625
# Class 119.0 recall = 0.05263157894736842
# Class 119.0 F1 Measure = 0.05714285714285714
# Class 120.0 precision = 0.2702702702702703
# Class 120.0 recall = 0.2222222222222222
# Class 120.0 F1 Measure = 0.24390243902439024
# Class 121.0 precision = 0.09302325581395349
# Class 121.0 recall = 0.08
# Class 121.0 F1 Measure = 0.08602150537634408
# Class 122.0 precision = 0.043478260869565216
# Class 122.0 recall = 0.05
# Class 122.0 F1 Measure = 0.046511627906976744
# Class 123.0 precision = 0.18181818181818182
# Class 123.0 recall = 0.12
# Class 123.0 F1 Measure = 0.14457831325301204
# Class 124.0 precision = 0.0625
# Class 124.0 recall = 0.05714285714285714
# Class 124.0 F1 Measure = 0.05970149253731344
# Class 125.0 precision = 0.09302325581395349
# Class 125.0 recall = 0.08
# Class 125.0 F1 Measure = 0.08602150537634408
# Class 126.0 precision = 0.11764705882352941
# Class 126.0 recall = 0.12121212121212122
# Class 126.0 F1 Measure = 0.11940298507462688
# Class 127.0 precision = 0.019230769230769232
# Class 127.0 recall = 0.023255813953488372
# Class 127.0 F1 Measure = 0.021052631578947368
# Class 128.0 precision = 0.1891891891891892
# Class 128.0 recall = 0.22580645161290322
# Class 128.0 F1 Measure = 0.2058823529411765
# Class 129.0 precision = 0.15151515151515152
# Class 129.0 recall = 0.09433962264150944
# Class 129.0 F1 Measure = 0.11627906976744186
# Class 130.0 precision = 0.07317073170731707
# Class 130.0 recall = 0.061224489795918366
# Class 130.0 F1 Measure = 0.06666666666666667
# Class 131.0 precision = 0.05714285714285714
# Class 131.0 recall = 0.04081632653061224
# Class 131.0 F1 Measure = 0.04761904761904761
# Class 132.0 precision = 0.09090909090909091
# Class 132.0 recall = 0.06521739130434782
# Class 132.0 F1 Measure = 0.0759493670886076
# Class 133.0 precision = 0.125
# Class 133.0 recall = 0.0975609756097561
# Class 133.0 F1 Measure = 0.10958904109589042
# Class 134.0 precision = 0.10869565217391304
# Class 134.0 recall = 0.15151515151515152
# Class 134.0 F1 Measure = 0.12658227848101267
# Class 135.0 precision = 0.1
# Class 135.0 recall = 0.10810810810810811
# Class 135.0 F1 Measure = 0.1038961038961039
# Class 136.0 precision = 0.15625
# Class 136.0 recall = 0.11904761904761904
# Class 136.0 F1 Measure = 0.13513513513513511
# Class 137.0 precision = 0.11904761904761904
# Class 137.0 recall = 0.12195121951219512
# Class 137.0 F1 Measure = 0.12048192771084337
# Class 138.0 precision = 0.14285714285714285
# Class 138.0 recall = 0.08695652173913043
# Class 138.0 F1 Measure = 0.1081081081081081
# Class 139.0 precision = 0.15384615384615385
# Class 139.0 recall = 0.125
# Class 139.0 F1 Measure = 0.13793103448275862
# Class 140.0 precision = 0.0
# Class 140.0 recall = 0.0
# Class 140.0 F1 Measure = 0.0
# Class 141.0 precision = 0.08571428571428572
# Class 141.0 recall = 0.05357142857142857
# Class 141.0 F1 Measure = 0.06593406593406592
# Class 142.0 precision = 0.18181818181818182
# Class 142.0 recall = 0.14285714285714285
# Class 142.0 F1 Measure = 0.16
# Class 143.0 precision = 0.0625
# Class 143.0 recall = 0.03636363636363636
# Class 143.0 F1 Measure = 0.04597701149425287
# Class 144.0 precision = 0.3076923076923077
# Class 144.0 recall = 0.34285714285714286
# Class 144.0 F1 Measure = 0.3243243243243243
# Class 145.0 precision = 0.06666666666666667
# Class 145.0 recall = 0.05714285714285714
# Class 145.0 F1 Measure = 0.061538461538461535
# Class 146.0 precision = 0.12
# Class 146.0 recall = 0.06818181818181818
# Class 146.0 F1 Measure = 0.08695652173913043
# Class 147.0 precision = 0.05555555555555555
# Class 147.0 recall = 0.05714285714285714
# Class 147.0 F1 Measure = 0.056338028169014086
# Class 148.0 precision = 0.09523809523809523
# Class 148.0 recall = 0.14814814814814814
# Class 148.0 F1 Measure = 0.11594202898550725
# Class 149.0 precision = 0.14705882352941177
# Class 149.0 recall = 0.2
# Class 149.0 F1 Measure = 0.16949152542372883
# Class 150.0 precision = 0.05128205128205128
# Class 150.0 recall = 0.08333333333333333
# Class 150.0 F1 Measure = 0.06349206349206349
# Class 151.0 precision = 0.13333333333333333
# Class 151.0 recall = 0.08333333333333333
# Class 151.0 F1 Measure = 0.10256410256410255
# Class 152.0 precision = 0.1388888888888889
# Class 152.0 recall = 0.15151515151515152
# Class 152.0 F1 Measure = 0.14492753623188404
# Class 153.0 precision = 0.07692307692307693
# Class 153.0 recall = 0.041666666666666664
# Class 153.0 F1 Measure = 0.05405405405405406
# Class 154.0 precision = 0.125
# Class 154.0 recall = 0.17857142857142858
# Class 154.0 F1 Measure = 0.14705882352941174
# Class 155.0 precision = 0.058823529411764705
# Class 155.0 recall = 0.058823529411764705
# Class 155.0 F1 Measure = 0.058823529411764705
# Class 156.0 precision = 0.17647058823529413
# Class 156.0 recall = 0.14634146341463414
# Class 156.0 F1 Measure = 0.16
# Class 157.0 precision = 0.0
# Class 157.0 recall = 0.0
# Class 157.0 F1 Measure = 0.0
# Class 158.0 precision = 0.03333333333333333
# Class 158.0 recall = 0.03225806451612903
# Class 158.0 F1 Measure = 0.03278688524590164
# Class 159.0 precision = 0.2413793103448276
# Class 159.0 recall = 0.18421052631578946
# Class 159.0 F1 Measure = 0.208955223880597
# Class 160.0 precision = 0.1111111111111111
# Class 160.0 recall = 0.08888888888888889
# Class 160.0 F1 Measure = 0.09876543209876543
# Class 161.0 precision = 0.0
# Class 161.0 recall = 0.0
# Class 161.0 F1 Measure = 0.0
# Class 162.0 precision = 0.1891891891891892
# Class 162.0 recall = 0.1891891891891892
# Class 162.0 F1 Measure = 0.18918918918918917
# Class 163.0 precision = 0.17142857142857143
# Class 163.0 recall = 0.15
# Class 163.0 F1 Measure = 0.16
# Class 164.0 precision = 0.16666666666666666
# Class 164.0 recall = 0.16129032258064516
# Class 164.0 F1 Measure = 0.16393442622950818
# Class 165.0 precision = 0.03333333333333333
# Class 165.0 recall = 0.017543859649122806
# Class 165.0 F1 Measure = 0.022988505747126436
# Class 166.0 precision = 0.037037037037037035
# Class 166.0 recall = 0.025
# Class 166.0 F1 Measure = 0.02985074626865672
# Class 167.0 precision = 0.08108108108108109
# Class 167.0 recall = 0.08108108108108109
# Class 167.0 F1 Measure = 0.08108108108108109
# Class 168.0 precision = 0.05714285714285714
# Class 168.0 recall = 0.06060606060606061
# Class 168.0 F1 Measure = 0.05882352941176471
# Class 169.0 precision = 0.06896551724137931
# Class 169.0 recall = 0.06666666666666667
# Class 169.0 F1 Measure = 0.06779661016949153
# Class 170.0 precision = 0.08571428571428572
# Class 170.0 recall = 0.06382978723404255
# Class 170.0 F1 Measure = 0.07317073170731707
# Class 171.0 precision = 0.16666666666666666
# Class 171.0 recall = 0.07692307692307693
# Class 171.0 F1 Measure = 0.10526315789473684
# Class 172.0 precision = 0.13333333333333333
# Class 172.0 recall = 0.13333333333333333
# Class 172.0 F1 Measure = 0.13333333333333333
# Class 173.0 precision = 0.030303030303030304
# Class 173.0 recall = 0.029411764705882353
# Class 173.0 F1 Measure = 0.02985074626865672
# Class 174.0 precision = 0.07692307692307693
# Class 174.0 recall = 0.0625
# Class 174.0 F1 Measure = 0.06896551724137931
# Class 175.0 precision = 0.10714285714285714
# Class 175.0 recall = 0.08108108108108109
# Class 175.0 F1 Measure = 0.0923076923076923
# Class 176.0 precision = 0.09090909090909091
# Class 176.0 recall = 0.13333333333333333
# Class 176.0 F1 Measure = 0.10810810810810811
# Class 177.0 precision = 0.06451612903225806
# Class 177.0 recall = 0.06451612903225806
# Class 177.0 F1 Measure = 0.06451612903225806
# Class 178.0 precision = 0.037037037037037035
# Class 178.0 recall = 0.037037037037037035
# Class 178.0 F1 Measure = 0.037037037037037035
# Class 179.0 precision = 0.06896551724137931
# Class 179.0 recall = 0.05555555555555555
# Class 179.0 F1 Measure = 0.061538461538461535
# Class 180.0 precision = 0.03225806451612903
# Class 180.0 recall = 0.05555555555555555
# Class 180.0 F1 Measure = 0.04081632653061224
# Class 181.0 precision = 0.10344827586206896
# Class 181.0 recall = 0.09090909090909091
# Class 181.0 F1 Measure = 0.0967741935483871
# Class 182.0 precision = 0.23809523809523808
# Class 182.0 recall = 0.16666666666666666
# Class 182.0 F1 Measure = 0.19607843137254902
# Class 183.0 precision = 0.07692307692307693
# Class 183.0 recall = 0.06060606060606061
# Class 183.0 F1 Measure = 0.06779661016949153
# Class 184.0 precision = 0.10526315789473684
# Class 184.0 recall = 0.05263157894736842
# Class 184.0 F1 Measure = 0.07017543859649122
# Class 185.0 precision = 0.16129032258064516
# Class 185.0 recall = 0.21739130434782608
# Class 185.0 F1 Measure = 0.18518518518518517
# Class 186.0 precision = 0.14285714285714285
# Class 186.0 recall = 0.15384615384615385
# Class 186.0 F1 Measure = 0.14814814814814817
# Class 187.0 precision = 0.03571428571428571
# Class 187.0 recall = 0.045454545454545456
# Class 187.0 F1 Measure = 0.04
# Class 188.0 precision = 0.0
# Class 188.0 recall = 0.0
# Class 188.0 F1 Measure = 0.0
# Class 189.0 precision = 0.08695652173913043
# Class 189.0 recall = 0.07142857142857142
# Class 189.0 F1 Measure = 0.0784313725490196
# Class 190.0 precision = 0.09090909090909091
# Class 190.0 recall = 0.06896551724137931
# Class 190.0 F1 Measure = 0.0784313725490196
# Class 191.0 precision = 0.125
# Class 191.0 recall = 0.14285714285714285
# Class 191.0 F1 Measure = 0.13333333333333333
# Class 192.0 precision = 0.0
# Class 192.0 recall = 0.0
# Class 192.0 F1 Measure = 0.0
# Class 193.0 precision = 0.0
# Class 193.0 recall = 0.0
# Class 193.0 F1 Measure = 0.0
# Class 194.0 precision = 0.06060606060606061
# Class 194.0 recall = 0.06896551724137931
# Class 194.0 F1 Measure = 0.06451612903225808
# Class 195.0 precision = 0.0
# Class 195.0 recall = 0.0
# Class 195.0 F1 Measure = 0.0
# Class 196.0 precision = 0.2857142857142857
# Class 196.0 recall = 0.20689655172413793
# Class 196.0 F1 Measure = 0.24000000000000002
# Class 197.0 precision = 0.09523809523809523
# Class 197.0 recall = 0.1111111111111111
# Class 197.0 F1 Measure = 0.10256410256410256
# Class 198.0 precision = 0.17647058823529413
# Class 198.0 recall = 0.10714285714285714
# Class 198.0 F1 Measure = 0.13333333333333333
# Class 199.0 precision = 0.0967741935483871
# Class 199.0 recall = 0.17647058823529413
# Class 199.0 F1 Measure = 0.125
# Class 200.0 precision = 0.034482758620689655
# Class 200.0 recall = 0.03571428571428571
# Class 200.0 F1 Measure = 0.03508771929824562
# Class 201.0 precision = 0.0
# Class 201.0 recall = 0.0
# Class 201.0 F1 Measure = 0.0
# Class 202.0 precision = 0.08
# Class 202.0 recall = 0.06666666666666667
# Class 202.0 F1 Measure = 0.07272727272727272
# Class 203.0 precision = 0.0
# Class 203.0 recall = 0.0
# Class 203.0 F1 Measure = 0.0
# Class 204.0 precision = 0.08695652173913043
# Class 204.0 recall = 0.1
# Class 204.0 F1 Measure = 0.09302325581395349
# Class 205.0 precision = 0.0
# Class 205.0 recall = 0.0
# Class 205.0 F1 Measure = 0.0
# Class 206.0 precision = 0.0
# Class 206.0 recall = 0.0
# Class 206.0 F1 Measure = 0.0
# Class 207.0 precision = 0.04
# Class 207.0 recall = 0.04
# Class 207.0 F1 Measure = 0.04
# Class 208.0 precision = 0.05
# Class 208.0 recall = 0.034482758620689655
# Class 208.0 F1 Measure = 0.04081632653061224
# Class 209.0 precision = 0.03571428571428571
# Class 209.0 recall = 0.045454545454545456
# Class 209.0 F1 Measure = 0.04
# Class 210.0 precision = 0.0
# Class 210.0 recall = 0.0
# Class 210.0 F1 Measure = 0.0
# Class 211.0 precision = 0.06666666666666667
# Class 211.0 recall = 0.027777777777777776
# Class 211.0 F1 Measure = 0.0392156862745098
# Class 212.0 precision = 0.047619047619047616
# Class 212.0 recall = 0.045454545454545456
# Class 212.0 F1 Measure = 0.046511627906976744
# Class 213.0 precision = 0.1111111111111111
# Class 213.0 recall = 0.17647058823529413
# Class 213.0 F1 Measure = 0.13636363636363638
# Class 214.0 precision = 0.08695652173913043
# Class 214.0 recall = 0.09523809523809523
# Class 214.0 F1 Measure = 0.0909090909090909
# Class 215.0 precision = 0.0
# Class 215.0 recall = 0.0
# Class 215.0 F1 Measure = 0.0
# Class 216.0 precision = 0.043478260869565216
# Class 216.0 recall = 0.034482758620689655
# Class 216.0 F1 Measure = 0.038461538461538464
# Class 217.0 precision = 0.0
# Class 217.0 recall = 0.0
# Class 217.0 F1 Measure = 0.0
# Class 218.0 precision = 0.0
# Class 218.0 recall = 0.0
# Class 218.0 F1 Measure = 0.0
# Class 219.0 precision = 0.13043478260869565
# Class 219.0 recall = 0.14285714285714285
# Class 219.0 F1 Measure = 0.13636363636363635
# Class 220.0 precision = 0.0
# Class 220.0 recall = 0.0
# Class 220.0 F1 Measure = 0.0
# Class 221.0 precision = 0.0
# Class 221.0 recall = 0.0
# Class 221.0 F1 Measure = 0.0
# Class 222.0 precision = 0.07692307692307693
# Class 222.0 recall = 0.10526315789473684
# Class 222.0 F1 Measure = 0.08888888888888889
# Class 223.0 precision = 0.045454545454545456
# Class 223.0 recall = 0.047619047619047616
# Class 223.0 F1 Measure = 0.046511627906976744
# Class 224.0 precision = 0.04
# Class 224.0 recall = 0.038461538461538464
# Class 224.0 F1 Measure = 0.0392156862745098
# Class 225.0 precision = 0.125
# Class 225.0 recall = 0.13043478260869565
# Class 225.0 F1 Measure = 0.1276595744680851
# Class 226.0 precision = 0.06666666666666667
# Class 226.0 recall = 0.034482758620689655
# Class 226.0 F1 Measure = 0.045454545454545456
# Class 227.0 precision = 0.045454545454545456
# Class 227.0 recall = 0.05
# Class 227.0 F1 Measure = 0.04761904761904762
# Class 228.0 precision = 0.1
# Class 228.0 recall = 0.10526315789473684
# Class 228.0 F1 Measure = 0.10256410256410256
# Class 229.0 precision = 0.0
# Class 229.0 recall = 0.0
# Class 229.0 F1 Measure = 0.0
# Class 230.0 precision = 0.047619047619047616
# Class 230.0 recall = 0.0625
# Class 230.0 F1 Measure = 0.05405405405405405
# Class 231.0 precision = 0.15384615384615385
# Class 231.0 recall = 0.2857142857142857
# Class 231.0 F1 Measure = 0.2
# Class 232.0 precision = 0.045454545454545456
# Class 232.0 recall = 0.058823529411764705
# Class 232.0 F1 Measure = 0.05128205128205128
# Class 233.0 precision = 0.05263157894736842
# Class 233.0 recall = 0.07692307692307693
# Class 233.0 F1 Measure = 0.0625
# Class 234.0 precision = 0.13636363636363635
# Class 234.0 recall = 0.23076923076923078
# Class 234.0 F1 Measure = 0.1714285714285714
# Class 235.0 precision = 0.041666666666666664
# Class 235.0 recall = 0.05263157894736842
# Class 235.0 F1 Measure = 0.04651162790697675
# Class 236.0 precision = 0.041666666666666664
# Class 236.0 recall = 0.041666666666666664
# Class 236.0 F1 Measure = 0.041666666666666664
# Class 237.0 precision = 0.11764705882352941
# Class 237.0 recall = 0.13333333333333333
# Class 237.0 F1 Measure = 0.125
# Class 238.0 precision = 0.03571428571428571
# Class 238.0 recall = 0.0625
# Class 238.0 F1 Measure = 0.045454545454545456
# Class 239.0 precision = 0.13333333333333333
# Class 239.0 recall = 0.1
# Class 239.0 F1 Measure = 0.1142857142857143
# Class 240.0 precision = 0.0
# Class 240.0 recall = 0.0
# Class 240.0 F1 Measure = 0.0
# Class 241.0 precision = 0.26666666666666666
# Class 241.0 recall = 0.16666666666666666
# Class 241.0 F1 Measure = 0.2051282051282051
# Class 242.0 precision = 0.09090909090909091
# Class 242.0 recall = 0.0625
# Class 242.0 F1 Measure = 0.07407407407407407
# Class 243.0 precision = 0.047619047619047616
# Class 243.0 recall = 0.07692307692307693
# Class 243.0 F1 Measure = 0.058823529411764705
# Class 244.0 precision = 0.11764705882352941
# Class 244.0 recall = 0.1111111111111111
# Class 244.0 F1 Measure = 0.11428571428571428
# Class 245.0 precision = 0.15384615384615385
# Class 245.0 recall = 0.19047619047619047
# Class 245.0 F1 Measure = 0.1702127659574468
# Class 246.0 precision = 0.0
# Class 246.0 recall = 0.0
# Class 246.0 F1 Measure = 0.0
# Class 247.0 precision = 0.05263157894736842
# Class 247.0 recall = 0.047619047619047616
# Class 247.0 F1 Measure = 0.05
# Class 248.0 precision = 0.125
# Class 248.0 recall = 0.08333333333333333
# Class 248.0 F1 Measure = 0.1
# Class 249.0 precision = 0.10526315789473684
# Class 249.0 recall = 0.13333333333333333
# Class 249.0 F1 Measure = 0.11764705882352941
# Class 250.0 precision = 0.06666666666666667
# Class 250.0 recall = 0.1111111111111111
# Class 250.0 F1 Measure = 0.08333333333333334
# Class 251.0 precision = 0.13636363636363635
# Class 251.0 recall = 0.2727272727272727
# Class 251.0 F1 Measure = 0.1818181818181818
# Class 252.0 precision = 0.07692307692307693
# Class 252.0 recall = 0.16666666666666666
# Class 252.0 F1 Measure = 0.10526315789473684
# Class 253.0 precision = 0.08695652173913043
# Class 253.0 recall = 0.14285714285714285
# Class 253.0 F1 Measure = 0.1081081081081081
# Class 254.0 precision = 0.15
# Class 254.0 recall = 0.17647058823529413
# Class 254.0 F1 Measure = 0.16216216216216214
# Class 255.0 precision = 0.21739130434782608
# Class 255.0 recall = 0.20833333333333334
# Class 255.0 F1 Measure = 0.2127659574468085
# Class 256.0 precision = 0.0
# Class 256.0 recall = 0.0
# Class 256.0 F1 Measure = 0.0
# Class 257.0 precision = 0.07142857142857142
# Class 257.0 recall = 0.058823529411764705
# Class 257.0 F1 Measure = 0.06451612903225808
# Class 258.0 precision = 0.0
# Class 258.0 recall = 0.0
# Class 258.0 F1 Measure = 0.0
# Class 259.0 precision = 0.17391304347826086
# Class 259.0 recall = 0.3333333333333333
# Class 259.0 F1 Measure = 0.22857142857142854
# Class 260.0 precision = 0.0
# Class 260.0 recall = 0.0
# Class 260.0 F1 Measure = 0.0
# Class 261.0 precision = 0.0
# Class 261.0 recall = 0.0
# Class 261.0 F1 Measure = 0.0
# Class 262.0 precision = 0.0
# Class 262.0 recall = 0.0
# Class 262.0 F1 Measure = 0.0
# Class 263.0 precision = 0.0
# Class 263.0 recall = 0.0
# Class 263.0 F1 Measure = 0.0
# Class 264.0 precision = 0.0
# Class 264.0 recall = 0.0
# Class 264.0 F1 Measure = 0.0
# Class 265.0 precision = 0.0
# Class 265.0 recall = 0.0
# Class 265.0 F1 Measure = 0.0
# Class 266.0 precision = 0.11764705882352941
# Class 266.0 recall = 0.13333333333333333
# Class 266.0 F1 Measure = 0.125
# Class 267.0 precision = 0.0
# Class 267.0 recall = 0.0
# Class 267.0 F1 Measure = 0.0
# Class 268.0 precision = 0.09523809523809523
# Class 268.0 recall = 0.2222222222222222
# Class 268.0 F1 Measure = 0.13333333333333333
# Class 269.0 precision = 0.0
# Class 269.0 recall = 0.0
# Class 269.0 F1 Measure = 0.0
# Class 270.0 precision = 0.13333333333333333
# Class 270.0 recall = 0.1111111111111111
# Class 270.0 F1 Measure = 0.1212121212121212
# Class 271.0 precision = 0.0
# Class 271.0 recall = 0.0
# Class 271.0 F1 Measure = 0.0
# Class 272.0 precision = 0.0
# Class 272.0 recall = 0.0
# Class 272.0 F1 Measure = 0.0
# Class 273.0 precision = 0.047619047619047616
# Class 273.0 recall = 0.1111111111111111
# Class 273.0 F1 Measure = 0.06666666666666667
# Class 274.0 precision = 0.0
# Class 274.0 recall = 0.0
# Class 274.0 F1 Measure = 0.0
# Class 275.0 precision = 0.05263157894736842
# Class 275.0 recall = 0.058823529411764705
# Class 275.0 F1 Measure = 0.05555555555555555
# Class 276.0 precision = 0.18181818181818182
# Class 276.0 recall = 0.09090909090909091
# Class 276.0 F1 Measure = 0.12121212121212123
# Class 277.0 precision = 0.0
# Class 277.0 recall = 0.0
# Class 277.0 F1 Measure = 0.0
# Class 278.0 precision = 0.05555555555555555
# Class 278.0 recall = 0.1
# Class 278.0 F1 Measure = 0.07142857142857142
# Class 279.0 precision = 0.0
# Class 279.0 recall = 0.0
# Class 279.0 F1 Measure = 0.0
# Class 280.0 precision = 0.09090909090909091
# Class 280.0 recall = 0.125
# Class 280.0 F1 Measure = 0.10526315789473685
# Class 281.0 precision = 0.0
# Class 281.0 recall = 0.0
# Class 281.0 F1 Measure = 0.0
# Class 282.0 precision = 0.0
# Class 282.0 recall = 0.0
# Class 282.0 F1 Measure = 0.0
# Class 283.0 precision = 0.07692307692307693
# Class 283.0 recall = 0.06666666666666667
# Class 283.0 F1 Measure = 0.07142857142857144
# Class 284.0 precision = 0.058823529411764705
# Class 284.0 recall = 0.07142857142857142
# Class 284.0 F1 Measure = 0.06451612903225808
# Class 285.0 precision = 0.0
# Class 285.0 recall = 0.0
# Class 285.0 F1 Measure = 0.0
# Class 286.0 precision = 0.0
# Class 286.0 recall = 0.0
# Class 286.0 F1 Measure = 0.0
# Class 287.0 precision = 0.041666666666666664
# Class 287.0 recall = 0.07142857142857142
# Class 287.0 F1 Measure = 0.052631578947368425
# Class 288.0 precision = 0.0
# Class 288.0 recall = 0.0
# Class 288.0 F1 Measure = 0.0
# Class 289.0 precision = 0.09090909090909091
# Class 289.0 recall = 0.058823529411764705
# Class 289.0 F1 Measure = 0.07142857142857142
# Class 290.0 precision = 0.08333333333333333
# Class 290.0 recall = 0.08333333333333333
# Class 290.0 F1 Measure = 0.08333333333333333
# Class 291.0 precision = 0.0
# Class 291.0 recall = 0.0
# Class 291.0 F1 Measure = 0.0
# Class 292.0 precision = 0.045454545454545456
# Class 292.0 recall = 0.07692307692307693
# Class 292.0 F1 Measure = 0.05714285714285715
# Class 293.0 precision = 0.0
# Class 293.0 recall = 0.0
# Class 293.0 F1 Measure = 0.0
# Class 294.0 precision = 0.0
# Class 294.0 recall = 0.0
# Class 294.0 F1 Measure = 0.0
# Class 295.0 precision = 0.0
# Class 295.0 recall = 0.0
# Class 295.0 F1 Measure = 0.0
# Class 296.0 precision = 0.0
# Class 296.0 recall = 0.0
# Class 296.0 F1 Measure = 0.0
# Class 297.0 precision = 0.55
# Class 297.0 recall = 0.7857142857142857
# Class 297.0 F1 Measure = 0.6470588235294117
# Class 298.0 precision = 0.058823529411764705
# Class 298.0 recall = 0.07692307692307693
# Class 298.0 F1 Measure = 0.06666666666666667
# Class 299.0 precision = 0.0
# Class 299.0 recall = 0.0
# Class 299.0 F1 Measure = 0.0
# Class 300.0 precision = 0.2857142857142857
# Class 300.0 recall = 0.4
# Class 300.0 F1 Measure = 0.3333333333333333
# Class 301.0 precision = 0.0
# Class 301.0 recall = 0.0
# Class 301.0 F1 Measure = 0.0
# Class 302.0 precision = 0.07142857142857142
# Class 302.0 recall = 0.05555555555555555
# Class 302.0 F1 Measure = 0.0625
# Class 303.0 precision = 0.0
# Class 303.0 recall = 0.0
# Class 303.0 F1 Measure = 0.0
# Class 304.0 precision = 0.19230769230769232
# Class 304.0 recall = 0.29411764705882354
# Class 304.0 F1 Measure = 0.23255813953488372
# Class 305.0 precision = 0.047619047619047616
# Class 305.0 recall = 0.125
# Class 305.0 F1 Measure = 0.06896551724137931
# Class 306.0 precision = 0.09090909090909091
# Class 306.0 recall = 0.2222222222222222
# Class 306.0 F1 Measure = 0.1290322580645161
# Class 307.0 precision = 0.21428571428571427
# Class 307.0 recall = 0.17647058823529413
# Class 307.0 F1 Measure = 0.1935483870967742
# Class 308.0 precision = 0.1111111111111111
# Class 308.0 recall = 0.14285714285714285
# Class 308.0 F1 Measure = 0.125
# Class 309.0 precision = 0.05555555555555555
# Class 309.0 recall = 0.06666666666666667
# Class 309.0 F1 Measure = 0.0606060606060606
# Class 310.0 precision = 0.0
# Class 310.0 recall = 0.0
# Class 310.0 F1 Measure = 0.0
# Class 311.0 precision = 0.05263157894736842
# Class 311.0 recall = 0.1
# Class 311.0 F1 Measure = 0.06896551724137931
# Class 312.0 precision = 0.07692307692307693
# Class 312.0 recall = 0.0625
# Class 312.0 F1 Measure = 0.06896551724137931
# Class 313.0 precision = 0.0
# Class 313.0 recall = 0.0
# Class 313.0 F1 Measure = 0.0
# Class 314.0 precision = 0.058823529411764705
# Class 314.0 recall = 0.07692307692307693
# Class 314.0 F1 Measure = 0.06666666666666667
# Class 315.0 precision = 0.0
# Class 315.0 recall = 0.0
# Class 315.0 F1 Measure = 0.0
# Class 316.0 precision = 0.058823529411764705
# Class 316.0 recall = 0.047619047619047616
# Class 316.0 F1 Measure = 0.05263157894736842
# Class 317.0 precision = 0.06666666666666667
# Class 317.0 recall = 0.125
# Class 317.0 F1 Measure = 0.08695652173913045
# Class 318.0 precision = 0.07692307692307693
# Class 318.0 recall = 0.1111111111111111
# Class 318.0 F1 Measure = 0.09090909090909093
# Class 319.0 precision = 0.0
# Class 319.0 recall = 0.0
# Class 319.0 F1 Measure = 0.0
# Class 320.0 precision = 0.0
# Class 320.0 recall = 0.0
# Class 320.0 F1 Measure = 0.0
# Class 321.0 precision = 0.0
# Class 321.0 recall = 0.0
# Class 321.0 F1 Measure = 0.0
# Class 322.0 precision = 0.05555555555555555
# Class 322.0 recall = 0.16666666666666666
# Class 322.0 F1 Measure = 0.08333333333333333
# Class 323.0 precision = 0.08333333333333333
# Class 323.0 recall = 0.058823529411764705
# Class 323.0 F1 Measure = 0.06896551724137931
# Class 324.0 precision = 0.0
# Class 324.0 recall = 0.0
# Class 324.0 F1 Measure = 0.0
# Class 325.0 precision = 0.0
# Class 325.0 recall = 0.0
# Class 325.0 F1 Measure = 0.0
# Class 326.0 precision = 0.0
# Class 326.0 recall = 0.0
# Class 326.0 F1 Measure = 0.0
# Class 327.0 precision = 0.0
# Class 327.0 recall = 0.0
# Class 327.0 F1 Measure = 0.0
# Class 328.0 precision = 0.13333333333333333
# Class 328.0 recall = 0.2857142857142857
# Class 328.0 F1 Measure = 0.18181818181818182
# Class 329.0 precision = 0.07142857142857142
# Class 329.0 recall = 0.07692307692307693
# Class 329.0 F1 Measure = 0.07407407407407408
# Class 330.0 precision = 0.0
# Class 330.0 recall = 0.0
# Class 330.0 F1 Measure = 0.0
# Class 331.0 precision = 0.0
# Class 331.0 recall = 0.0
# Class 331.0 F1 Measure = 0.0
# Class 332.0 precision = 0.0
# Class 332.0 recall = 0.0
# Class 332.0 F1 Measure = 0.0
# Class 333.0 precision = 0.0
# Class 333.0 recall = 0.0
# Class 333.0 F1 Measure = 0.0
# Class 334.0 precision = 0.0
# Class 334.0 recall = 0.0
# Class 334.0 F1 Measure = 0.0
# Class 335.0 precision = 0.14285714285714285
# Class 335.0 recall = 0.18181818181818182
# Class 335.0 F1 Measure = 0.16
# Class 336.0 precision = 0.1
# Class 336.0 recall = 0.16666666666666666
# Class 336.0 F1 Measure = 0.125
# Class 337.0 precision = 0.0
# Class 337.0 recall = 0.0
# Class 337.0 F1 Measure = 0.0
# Class 338.0 precision = 0.0
# Class 338.0 recall = 0.0
# Class 338.0 F1 Measure = 0.0
# Class 339.0 precision = 0.14285714285714285
# Class 339.0 recall = 0.1111111111111111
# Class 339.0 F1 Measure = 0.125
# Class 340.0 precision = 0.058823529411764705
# Class 340.0 recall = 0.1
# Class 340.0 F1 Measure = 0.07407407407407408
# Class 341.0 precision = 0.0
# Class 341.0 recall = 0.0
# Class 341.0 F1 Measure = 0.0
# Class 342.0 precision = 0.08333333333333333
# Class 342.0 recall = 0.1111111111111111
# Class 342.0 F1 Measure = 0.09523809523809525
# Class 343.0 precision = 0.0
# Class 343.0 recall = 0.0
# Class 343.0 F1 Measure = 0.0
# Class 344.0 precision = 0.13333333333333333
# Class 344.0 recall = 0.4
# Class 344.0 F1 Measure = 0.2
# Class 345.0 precision = 0.0
# Class 345.0 recall = 0.0
# Class 345.0 F1 Measure = 0.0
# Class 346.0 precision = 0.0
# Class 346.0 recall = 0.0
# Class 346.0 F1 Measure = 0.0
# Class 347.0 precision = 0.2
# Class 347.0 recall = 0.5
# Class 347.0 F1 Measure = 0.28571428571428575
# Class 348.0 precision = 0.0625
# Class 348.0 recall = 0.1111111111111111
# Class 348.0 F1 Measure = 0.08
# Class 349.0 precision = 0.06666666666666667
# Class 349.0 recall = 0.1111111111111111
# Class 349.0 F1 Measure = 0.08333333333333334
# Class 350.0 precision = 0.0
# Class 350.0 recall = 0.0
# Class 350.0 F1 Measure = 0.0
# Class 351.0 precision = 0.07692307692307693
# Class 351.0 recall = 0.08333333333333333
# Class 351.0 F1 Measure = 0.08
# Class 352.0 precision = 0.0
# Class 352.0 recall = 0.0
# Class 352.0 F1 Measure = 0.0
# Class 353.0 precision = 0.16666666666666666
# Class 353.0 recall = 0.16666666666666666
# Class 353.0 F1 Measure = 0.16666666666666666
# Class 354.0 precision = 0.0625
# Class 354.0 recall = 0.1
# Class 354.0 F1 Measure = 0.07692307692307693
# Class 355.0 precision = 0.0
# Class 355.0 recall = 0.0
# Class 355.0 F1 Measure = 0.0
# Class 356.0 precision = 0.0
# Class 356.0 recall = 0.0
# Class 356.0 F1 Measure = 0.0
# Class 357.0 precision = 0.125
# Class 357.0 recall = 0.25
# Class 357.0 F1 Measure = 0.16666666666666666
# Class 358.0 precision = 0.0
# Class 358.0 recall = 0.0
# Class 358.0 F1 Measure = 0.0
# Class 359.0 precision = 0.09090909090909091
# Class 359.0 recall = 0.2
# Class 359.0 F1 Measure = 0.12500000000000003
# Class 360.0 precision = 0.07142857142857142
# Class 360.0 recall = 0.08333333333333333
# Class 360.0 F1 Measure = 0.07692307692307691
# Class 361.0 precision = 0.0
# Class 361.0 recall = 0.0
# Class 361.0 F1 Measure = 0.0
# Class 362.0 not in this set!
# Class 363.0 precision = 0.1
# Class 363.0 recall = 0.047619047619047616
# Class 363.0 F1 Measure = 0.06451612903225806
# Class 364.0 precision = 0.0
# Class 364.0 recall = 0.0
# Class 364.0 F1 Measure = 0.0
# Class 365.0 precision = 0.15384615384615385
# Class 365.0 recall = 0.2
# Class 365.0 F1 Measure = 0.17391304347826086
# Class 366.0 precision = 0.0625
# Class 366.0 recall = 0.125
# Class 366.0 F1 Measure = 0.08333333333333333
# Class 367.0 precision = 0.36363636363636365
# Class 367.0 recall = 0.2222222222222222
# Class 367.0 F1 Measure = 0.27586206896551724
# Class 368.0 precision = 0.0
# Class 368.0 recall = 0.0
# Class 368.0 F1 Measure = 0.0
# Class 369.0 precision = 0.0
# Class 369.0 recall = 0.0
# Class 369.0 F1 Measure = 0.0
# Class 370.0 precision = 0.0
# Class 370.0 recall = 0.0
# Class 370.0 F1 Measure = 0.0
# Class 371.0 precision = 0.0
# Class 371.0 recall = 0.0
# Class 371.0 F1 Measure = 0.0
# Class 372.0 precision = 0.07692307692307693
# Class 372.0 recall = 0.3333333333333333
# Class 372.0 F1 Measure = 0.125
# Class 373.0 precision = 0.07142857142857142
# Class 373.0 recall = 0.08333333333333333
# Class 373.0 F1 Measure = 0.07692307692307691
# Class 374.0 precision = 0.0
# Class 374.0 recall = 0.0
# Class 374.0 F1 Measure = 0.0
# Class 375.0 precision = 0.0
# Class 375.0 recall = 0.0
# Class 375.0 F1 Measure = 0.0
# Class 376.0 precision = 0.0
# Class 376.0 recall = 0.0
# Class 376.0 F1 Measure = 0.0
# Class 377.0 precision = 0.0
# Class 377.0 recall = 0.0
# Class 377.0 F1 Measure = 0.0
# Class 378.0 precision = 0.0
# Class 378.0 recall = 0.0
# Class 378.0 F1 Measure = 0.0
# Class 379.0 precision = 0.05
# Class 379.0 recall = 0.125
# Class 379.0 F1 Measure = 0.07142857142857144
# Class 380.0 precision = 0.0
# Class 380.0 recall = 0.0
# Class 380.0 F1 Measure = 0.0
# Class 381.0 precision = 0.15384615384615385
# Class 381.0 recall = 0.2
# Class 381.0 F1 Measure = 0.17391304347826086
# Class 382.0 precision = 0.0
# Class 382.0 recall = 0.0
# Class 382.0 F1 Measure = 0.0
# Class 383.0 precision = 0.07142857142857142
# Class 383.0 recall = 0.2
# Class 383.0 F1 Measure = 0.10526315789473682
# Class 384.0 precision = 0.0
# Class 384.0 recall = 0.0
# Class 384.0 F1 Measure = 0.0
# Class 385.0 precision = 0.1
# Class 385.0 recall = 0.1
# Class 385.0 F1 Measure = 0.10000000000000002
# Class 386.0 precision = 0.0
# Class 386.0 recall = 0.0
# Class 386.0 F1 Measure = 0.0
# Class 387.0 precision = 0.16666666666666666
# Class 387.0 recall = 0.13333333333333333
# Class 387.0 F1 Measure = 0.14814814814814814
# Class 388.0 precision = 0.0
# Class 388.0 recall = 0.0
# Class 388.0 F1 Measure = 0.0
# Class 389.0 precision = 0.16666666666666666
# Class 389.0 recall = 0.2857142857142857
# Class 389.0 F1 Measure = 0.2105263157894737
# Class 390.0 precision = 0.0
# Class 390.0 recall = 0.0
# Class 390.0 F1 Measure = 0.0
# Class 391.0 precision = 0.1
# Class 391.0 recall = 0.16666666666666666
# Class 391.0 F1 Measure = 0.125
# Class 392.0 precision = 0.0
# Class 392.0 recall = 0.0
# Class 392.0 F1 Measure = 0.0
# Class 393.0 precision = 0.0
# Class 393.0 recall = 0.0
# Class 393.0 F1 Measure = 0.0
# Class 394.0 precision = 0.0
# Class 394.0 recall = 0.0
# Class 394.0 F1 Measure = 0.0
# Class 395.0 precision = 0.13333333333333333
# Class 395.0 recall = 0.6666666666666666
# Class 395.0 F1 Measure = 0.2222222222222222
# Class 396.0 precision = 0.14285714285714285
# Class 396.0 recall = 0.2857142857142857
# Class 396.0 F1 Measure = 0.19047619047619047
# Class 397.0 precision = 0.0
# Class 397.0 recall = 0.0
# Class 397.0 F1 Measure = 0.0
# Class 398.0 precision = 0.1
# Class 398.0 recall = 0.1
# Class 398.0 F1 Measure = 0.10000000000000002
# Class 399.0 precision = 0.0625
# Class 399.0 recall = 0.14285714285714285
# Class 399.0 F1 Measure = 0.08695652173913043
# Class 400.0 precision = 0.18181818181818182
# Class 400.0 recall = 0.2222222222222222
# Class 400.0 F1 Measure = 0.19999999999999998
# Class 401.0 precision = 0.0
# Class 401.0 recall = 0.0
# Class 401.0 F1 Measure = 0.0
# Class 402.0 precision = 0.0
# Class 402.0 recall = 0.0
# Class 402.0 F1 Measure = 0.0
# Class 403.0 precision = 0.08333333333333333
# Class 403.0 recall = 0.1
# Class 403.0 F1 Measure = 0.0909090909090909
# Class 404.0 precision = 0.0
# Class 404.0 recall = 0.0
# Class 404.0 F1 Measure = 0.0
# Class 405.0 precision = 0.0
# Class 405.0 recall = 0.0
# Class 405.0 F1 Measure = 0.0
# Class 406.0 precision = 0.0
# Class 406.0 recall = 0.0
# Class 406.0 F1 Measure = 0.0
# Class 407.0 precision = 0.08333333333333333
# Class 407.0 recall = 0.25
# Class 407.0 F1 Measure = 0.125
# Class 408.0 precision = 0.0
# Class 408.0 recall = 0.0
# Class 408.0 F1 Measure = 0.0
# Class 409.0 precision = 0.0
# Class 409.0 recall = 0.0
# Class 409.0 F1 Measure = 0.0
# Class 410.0 precision = 0.0
# Class 410.0 recall = 0.0
# Class 410.0 F1 Measure = 0.0
# Class 411.0 precision = 0.0
# Class 411.0 recall = 0.0
# Class 411.0 F1 Measure = 0.0
# Class 412.0 precision = 0.0
# Class 412.0 recall = 0.0
# Class 412.0 F1 Measure = 0.0
# Class 413.0 precision = 0.07692307692307693
# Class 413.0 recall = 0.16666666666666666
# Class 413.0 F1 Measure = 0.10526315789473684
# Class 414.0 precision = 0.07142857142857142
# Class 414.0 recall = 0.125
# Class 414.0 F1 Measure = 0.09090909090909091
# Class 415.0 precision = 0.0
# Class 415.0 recall = 0.0
# Class 415.0 F1 Measure = 0.0
# Class 416.0 precision = 0.0
# Class 416.0 recall = 0.0
# Class 416.0 F1 Measure = 0.0
# Class 417.0 precision = 0.125
# Class 417.0 recall = 0.16666666666666666
# Class 417.0 F1 Measure = 0.14285714285714288
# Class 418.0 precision = 0.0
# Class 418.0 recall = 0.0
# Class 418.0 F1 Measure = 0.0
# Class 419.0 precision = 0.0
# Class 419.0 recall = 0.0
# Class 419.0 F1 Measure = 0.0
# Class 420.0 precision = 0.0
# Class 420.0 recall = 0.0
# Class 420.0 F1 Measure = 0.0
# Class 421.0 precision = 0.125
# Class 421.0 recall = 0.14285714285714285
# Class 421.0 F1 Measure = 0.13333333333333333
# Class 422.0 precision = 0.0
# Class 422.0 recall = 0.0
# Class 422.0 F1 Measure = 0.0
# Class 423.0 precision = 0.06666666666666667
# Class 423.0 recall = 0.14285714285714285
# Class 423.0 F1 Measure = 0.09090909090909091
# Class 424.0 precision = 0.0
# Class 424.0 recall = 0.0
# Class 424.0 F1 Measure = 0.0
# Class 425.0 precision = 0.0
# Class 425.0 recall = 0.0
# Class 425.0 F1 Measure = 0.0
# Class 426.0 precision = 0.07692307692307693
# Class 426.0 recall = 0.2
# Class 426.0 F1 Measure = 0.1111111111111111
# Class 427.0 precision = 0.125
# Class 427.0 recall = 0.25
# Class 427.0 F1 Measure = 0.16666666666666666
# Class 428.0 precision = 0.0
# Class 428.0 recall = 0.0
# Class 428.0 F1 Measure = 0.0
# Class 429.0 precision = 0.0
# Class 429.0 recall = 0.0
# Class 429.0 F1 Measure = 0.0
# Class 430.0 precision = 0.0
# Class 430.0 recall = 0.0
# Class 430.0 F1 Measure = 0.0
# Class 431.0 precision = 0.15384615384615385
# Class 431.0 recall = 0.2222222222222222
# Class 431.0 F1 Measure = 0.18181818181818185
# Class 432.0 precision = 0.3333333333333333
# Class 432.0 recall = 0.36363636363636365
# Class 432.0 F1 Measure = 0.34782608695652173
# Class 433.0 precision = 0.0
# Class 433.0 recall = 0.0
# Class 433.0 F1 Measure = 0.0
# Class 434.0 precision = 0.08333333333333333
# Class 434.0 recall = 0.25
# Class 434.0 F1 Measure = 0.125
# Class 435.0 precision = 0.125
# Class 435.0 recall = 0.2
# Class 435.0 F1 Measure = 0.15384615384615385
# Class 436.0 precision = 0.0
# Class 436.0 recall = 0.0
# Class 436.0 F1 Measure = 0.0
# Class 437.0 precision = 0.0
# Class 437.0 recall = 0.0
# Class 437.0 F1 Measure = 0.0
# Class 438.0 precision = 0.0625
# Class 438.0 recall = 0.5
# Class 438.0 F1 Measure = 0.1111111111111111
# Class 439.0 precision = 0.0
# Class 439.0 recall = 0.0
# Class 439.0 F1 Measure = 0.0
# Class 440.0 precision = 0.06666666666666667
# Class 440.0 recall = 0.5
# Class 440.0 F1 Measure = 0.11764705882352941
# Class 441.0 precision = 0.0
# Class 441.0 recall = 0.0
# Class 441.0 F1 Measure = 0.0
# Class 442.0 precision = 0.0
# Class 442.0 recall = 0.0
# Class 442.0 F1 Measure = 0.0
# Class 443.0 precision = 0.1111111111111111
# Class 443.0 recall = 0.3333333333333333
# Class 443.0 F1 Measure = 0.16666666666666666
# Class 444.0 precision = 0.0
# Class 444.0 recall = 0.0
# Class 444.0 F1 Measure = 0.0
# Class 445.0 precision = 0.0
# Class 445.0 recall = 0.0
# Class 445.0 F1 Measure = 0.0
# Class 446.0 precision = 0.0
# Class 446.0 recall = 0.0
# Class 446.0 F1 Measure = 0.0
# Class 447.0 precision = 0.0
# Class 447.0 recall = 0.0
# Class 447.0 F1 Measure = 0.0
# Class 448.0 precision = 0.0
# Class 448.0 recall = 0.0
# Class 448.0 F1 Measure = 0.0
# Class 449.0 precision = 0.0
# Class 449.0 recall = 0.0
# Class 449.0 F1 Measure = 0.0
# Class 450.0 precision = 0.0625
# Class 450.0 recall = 0.125
# Class 450.0 F1 Measure = 0.08333333333333333
# Class 451.0 precision = 0.0
# Class 451.0 recall = 0.0
# Class 451.0 F1 Measure = 0.0
# Class 452.0 precision = 0.1
# Class 452.0 recall = 0.16666666666666666
# Class 452.0 F1 Measure = 0.125
# Class 453.0 precision = 0.09090909090909091
# Class 453.0 recall = 0.5
# Class 453.0 F1 Measure = 0.15384615384615385
# Class 454.0 precision = 0.058823529411764705
# Class 454.0 recall = 0.2
# Class 454.0 F1 Measure = 0.0909090909090909
# Class 455.0 precision = 0.0
# Class 455.0 recall = 0.0
# Class 455.0 F1 Measure = 0.0
# Class 456.0 precision = 0.1111111111111111
# Class 456.0 recall = 0.16666666666666666
# Class 456.0 F1 Measure = 0.13333333333333333
# Class 457.0 precision = 0.06666666666666667
# Class 457.0 recall = 0.14285714285714285
# Class 457.0 F1 Measure = 0.09090909090909091
# Class 458.0 precision = 0.14285714285714285
# Class 458.0 recall = 0.125
# Class 458.0 F1 Measure = 0.13333333333333333
# Class 459.0 precision = 0.0
# Class 459.0 recall = 0.0
# Class 459.0 F1 Measure = 0.0
# Class 460.0 precision = 0.1
# Class 460.0 recall = 0.25
# Class 460.0 F1 Measure = 0.14285714285714288
# Class 461.0 precision = 0.0
# Class 461.0 recall = 0.0
# Class 461.0 F1 Measure = 0.0
# Class 462.0 precision = 0.0
# Class 462.0 recall = 0.0
# Class 462.0 F1 Measure = 0.0
# Class 463.0 precision = 0.0
# Class 463.0 recall = 0.0
# Class 463.0 F1 Measure = 0.0
# Class 464.0 precision = 0.08333333333333333
# Class 464.0 recall = 0.2
# Class 464.0 F1 Measure = 0.11764705882352941
# Class 465.0 precision = 0.0
# Class 465.0 recall = 0.0
# Class 465.0 F1 Measure = 0.0
# Class 466.0 precision = 0.0
# Class 466.0 recall = 0.0
# Class 466.0 F1 Measure = 0.0
# Class 467.0 precision = 0.0
# Class 467.0 recall = 0.0
# Class 467.0 F1 Measure = 0.0
# Class 468.0 precision = 0.07692307692307693
# Class 468.0 recall = 0.2
# Class 468.0 F1 Measure = 0.1111111111111111
# Class 469.0 precision = 0.09090909090909091
# Class 469.0 recall = 0.25
# Class 469.0 F1 Measure = 0.13333333333333333
# Class 470.0 precision = 0.08333333333333333
# Class 470.0 recall = 0.25
# Class 470.0 F1 Measure = 0.125
# Class 471.0 precision = 0.25
# Class 471.0 recall = 0.125
# Class 471.0 F1 Measure = 0.16666666666666666
# Class 472.0 precision = 0.07142857142857142
# Class 472.0 recall = 0.3333333333333333
# Class 472.0 F1 Measure = 0.11764705882352941
# Class 473.0 precision = 0.0
# Class 473.0 recall = 0.0
# Class 473.0 F1 Measure = 0.0
# Class 474.0 precision = 0.0
# Class 474.0 recall = 0.0
# Class 474.0 F1 Measure = 0.0
# Class 475.0 precision = 0.0
# Class 475.0 recall = 0.0
# Class 475.0 F1 Measure = 0.0
# Class 476.0 precision = 0.0
# Class 476.0 recall = 0.0
# Class 476.0 F1 Measure = 0.0
# Class 477.0 precision = 0.0
# Class 477.0 recall = 0.0
# Class 477.0 F1 Measure = 0.0
# Class 478.0 precision = 0.0
# Class 478.0 recall = 0.0
# Class 478.0 F1 Measure = 0.0
# Class 479.0 precision = 0.0
# Class 479.0 recall = 0.0
# Class 479.0 F1 Measure = 0.0
# Class 480.0 precision = 0.0
# Class 480.0 recall = 0.0
# Class 480.0 F1 Measure = 0.0
# Class 481.0 precision = 0.0
# Class 481.0 recall = 0.0
# Class 481.0 F1 Measure = 0.0
# Class 482.0 precision = 0.0
# Class 482.0 recall = 0.0
# Class 482.0 F1 Measure = 0.0
# Class 483.0 precision = 0.07142857142857142
# Class 483.0 recall = 0.2
# Class 483.0 F1 Measure = 0.10526315789473682
# Class 484.0 precision = 0.0
# Class 484.0 recall = 0.0
# Class 484.0 F1 Measure = 0.0
# Class 485.0 precision = 0.0
# Class 485.0 recall = 0.0
# Class 485.0 F1 Measure = 0.0
# Class 486.0 precision = 0.0
# Class 486.0 recall = 0.0
# Class 486.0 F1 Measure = 0.0
# Class 487.0 precision = 0.08333333333333333
# Class 487.0 recall = 0.25
# Class 487.0 F1 Measure = 0.125
# Class 488.0 precision = 0.0
# Class 488.0 recall = 0.0
# Class 488.0 F1 Measure = 0.0
# Class 489.0 precision = 0.14285714285714285
# Class 489.0 recall = 0.16666666666666666
# Class 489.0 F1 Measure = 0.15384615384615383
# Class 490.0 precision = 0.0
# Class 490.0 recall = 0.0
# Class 490.0 F1 Measure = 0.0
# Class 491.0 precision = 0.09090909090909091
# Class 491.0 recall = 0.25
# Class 491.0 F1 Measure = 0.13333333333333333
# Class 492.0 precision = 0.0
# Class 492.0 recall = 0.0
# Class 492.0 F1 Measure = 0.0
# Class 493.0 precision = 0.0
# Class 493.0 recall = 0.0
# Class 493.0 F1 Measure = 0.0
# Class 494.0 precision = 0.1111111111111111
# Class 494.0 recall = 0.125
# Class 494.0 F1 Measure = 0.11764705882352941
# Class 495.0 precision = 0.0
# Class 495.0 recall = 0.0
# Class 495.0 F1 Measure = 0.0
# Class 496.0 precision = 0.1111111111111111
# Class 496.0 recall = 0.25
# Class 496.0 F1 Measure = 0.15384615384615383
# Class 497.0 precision = 0.0
# Class 497.0 recall = 0.0
# Class 497.0 F1 Measure = 0.0
# Class 498.0 precision = 0.09090909090909091
# Class 498.0 recall = 0.5
# Class 498.0 F1 Measure = 0.15384615384615385
# Class 499.0 precision = 0.0
# Class 499.0 recall = 0.0
# Class 499.0 F1 Measure = 0.0

# %%
top_df.select(["tag", "tag_idx", "prediction", "predicted_tag"]).show()
# Out:
# +------------------+-------+----------+--------------------+
# |               tag|tag_idx|prediction|       predicted_tag|
# +------------------+-------+----------+--------------------+
# |  active-directory|  219.0|     467.0|windows-server-20...|
# |            jquery|    0.0|      63.0|            function|
# |       objective-c|    6.0|      13.0|                 xml|
# |              ios6|  446.0|     478.0|      iphone-sdk-4.0|
# |        coldfusion|  331.0|      65.0|               query|
# |              .net|    1.0|       6.0|         objective-c|
# |        javascript|    9.0|     194.0|            servlets|
# |             swing|   26.0|      79.0|                  qt|
# |       objective-c|    6.0|       6.0|         objective-c|
# |visual-studio-2010|   36.0|     115.0|  visual-studio-2008|
# |            jquery|    0.0|      12.0|               regex|
# |               stl|  239.0|     216.0|                 svn|
# |               sql|   11.0|       2.0|               mysql|
# |       codeigniter|   89.0|       4.0|                html|
# |  web-applications|  165.0|      60.0|           templates|
# |             forms|   43.0|     155.0|              design|
# |     ruby-on-rails|   70.0|      11.0|                 sql|
# |        batch-file|  379.0|     286.0|               batch|
# |           caching|  154.0|      44.0|              spring|
# |             swing|   26.0|      26.0|               swing|
# +------------------+-------+----------+--------------------+
# only showing top 20 rows

# %%
from pyspark.mllib.evaluation import MulticlassMetrics
import pandas as pd


def get_label_metrics(results_df, ground_truth_col='tag_idx', prediction_col='prediction'):
    """Get pandas dataframe of top 10 tags with metrics from top_df

    Params: 
        results_df (pyspark DataFrame): top_df to get metrics of

    Returns:
        (pd.DataFrame): pandas dataframe in form of {column: [row_data]} for plotting
    """
    labels_and_predictions = results_df.select([ground_truth_col, prediction_col])
    # Instantiate metrics object
    metrics = MulticlassMetrics(labels_and_predictions.rdd)

    #get dict of labels to plot
    label_metrics = {}

    # Statistics by class
    labels = df.rdd.map(lambda lp: lp.tag_idx).distinct().collect()
    # print(labels)
    for label in sorted(labels):
        prec_recall_fMeasure = ()
        try:
            prec = metrics.precision(label)
            recall = metrics.recall(label)
            fMeasure = metrics.fMeasure(label, beta=1.0)
            prec_recall_fMeasure = (fMeasure, prec, recall) 
            label_metrics[label] = prec_recall_fMeasure
        except: 
            label_metrics[label] = (0,0,0)

    # get tags in string form: 
    tags = results_df.select(['tag', 'tag_idx']).distinct().collect()
    tag_pairs = {x['tag_idx']: x['tag'] for x in tags}

    # Convert tag classes into strings 
    tag_metrics = {}
    for tag_index in tag_pairs: 
        tag_metrics[tag_pairs[tag_index]] = label_metrics[tag_index]

    # Top 10 tags
    top_10_tags = sorted(tag_metrics, key=lambda x: tag_metrics[x][0], reverse=True)[:10]

    # Get ready for plotting
    plot_dict = {}
    tag_list = []
    f1_list = []
    precision_list = []
    recall_list = []

    for tag in top_10_tags:
        tag_list.append(tag)
        f1_list.append(tag_metrics[tag][0])
        precision_list.append(tag_metrics[tag][1])
        recall_list.append(tag_metrics[tag][2])

    plot_df = pd.DataFrame({"Tag": tag_list, "F1Measure": f1_list, "Precision":precision_list, "Recall":recall_list})
    
    return plot_df

# %%
plot_df = get_label_metrics(top_df)
print(plot_df)
# Out:
#               Tag  F1Measure  Precision    Recall
# 0    group-theory   0.647059   0.550000  0.785714
# 1           mysql   0.446334   0.429448  0.464602
# 2          arrays   0.423480   0.431624  0.415638
# 3        generics   0.422018   0.425926  0.418182
# 4             css   0.402532   0.450425  0.363844
# 5           regex   0.375839   0.398104  0.355932
# 6           swing   0.361842   0.381944  0.343750
# 7             xml   0.361809   0.378947  0.346154
# 8  measure-theory   0.347826   0.333333  0.363636
# 9       templates   0.340741   0.403509  0.294872

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="Tag", y="F1Measure", data=plot_df, ax=ax)
fig.show()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/kailunzhang/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# /Users/kailunzhang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="Tag", y="Precision", data=plot_df, ax=ax)
fig.show()
# Out:
# /Users/kailunzhang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="Tag", y="Recall", data=plot_df, ax=ax)
fig.show()
# Out:
# /Users/kailunzhang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """

# %%
lr_trad = 0.187

rf_trad = 0.247
this_dict = {'Models': ["LR", "RF"], "F1": [lr_trad, rf_trad]}

seaborn_df = pd.DataFrame.from_dict(this_dict)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="Models", y="F1", data=seaborn_df, ax =ax)
fig.show()
# Out:
# /Users/kailunzhang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if __name__ == '__main__':
