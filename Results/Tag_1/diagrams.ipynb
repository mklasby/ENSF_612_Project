# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('runs.csv', header=0)
df
# Out:
#                               Run ID  Name Source Type  \
# 0   00c4733daf664bb2a8a963198a793e4f   NaN         NaN
# 1   2377f92e6b6644debacbebb62c12743a   NaN         NaN
# 2   760ffbfaf09b455cba42c1931205d1ec   NaN         NaN
# 3   2abe293bd76f4fac85ae4cd0b585493e   NaN         NaN
# 4   52852f5b06dc403790fac117508eb8c9   NaN         NaN
# 5   47a17112ce244e00ba493582a284d4a3   NaN         NaN
# 6   7dc1f2d55c9d4bfebd20d273072b4a4f   NaN         NaN
# 7   bd7a035ead88441ba93ca4b48f3246f6   NaN         NaN
# 8   248866819b8a4d9289bc9730f616ad06   NaN         NaN
# 9   070dbb5610d3442a9ab0909074a79f10   NaN         NaN
# 10  753f7196d6454c64b59e4640265be4d0   NaN         NaN
# 11  832706c383ea4adba8329701e77e7b9c   NaN         NaN
# 12  45d486f45ff54440bcc7d282346f23cf   NaN         NaN
# 13  d84e43bb568648a3a0d86777d8524d30   NaN         NaN
# 14  53e4ea622af74bd199024a9bdbb9e146   NaN         NaN
# 15  29caa90dda3d45ac826ac0efbf2375b6   NaN         NaN
# ...

# %%
model_name = "RandomForestClassifier"
rf = df[df.mlModelClass.str.contains(model_name)]

# %%
rf
# Out:
#                               Run ID  Name Source Type Source Name  \
# 0   00c4733daf664bb2a8a963198a793e4f   NaN         NaN         NaN
# 1   2377f92e6b6644debacbebb62c12743a   NaN         NaN         NaN
# 2   760ffbfaf09b455cba42c1931205d1ec   NaN         NaN         NaN
# 3   2abe293bd76f4fac85ae4cd0b585493e   NaN         NaN         NaN
# 4   52852f5b06dc403790fac117508eb8c9   NaN         NaN         NaN
# 5   47a17112ce244e00ba493582a284d4a3   NaN         NaN         NaN
# 6   7dc1f2d55c9d4bfebd20d273072b4a4f   NaN         NaN         NaN
# 7   bd7a035ead88441ba93ca4b48f3246f6   NaN         NaN         NaN
# 8   248866819b8a4d9289bc9730f616ad06   NaN         NaN         NaN
# 9   070dbb5610d3442a9ab0909074a79f10   NaN         NaN         NaN
# 10  753f7196d6454c64b59e4640265be4d0   NaN         NaN         NaN
# 11  832706c383ea4adba8329701e77e7b9c   NaN         NaN         NaN
# 12  45d486f45ff54440bcc7d282346f23cf   NaN         NaN         NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="maxDepth", y="f1", hue = "numTrees", data=rf, ax=ax)
fig.show()
plt.savefig("Tuning_RandomForestBar")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.lineplot(x="maxDepth", y="f1", hue = "numTrees", data=rf, marker="o", ax=ax)
fig.show()
plt.savefig("Tuning_RandomForestLine")

# %%
df = pd.read_csv('lr_grid_search.csv', header=0)
lr =df 
lr
# Out:
#     regParam  elasticNetParam  fitIntercept  accuracy  weighted F1
# 0       0.00              0.0         False  0.391488     0.394165
# 1       0.00              0.0          True  0.396406     0.405314
# 2       0.00              0.5         False  0.391488     0.394165
# 3       0.00              0.5          True  0.395904     0.405006
# 4       0.00              1.0         False  0.391488     0.394165
# 5       0.00              1.0          True  0.395603     0.404686
# 6       0.01              0.0         False  0.416884     0.467708
# 7       0.01              0.0          True  0.408151     0.465576
# 8       0.01              0.5         False  0.369705     0.427934
# 9       0.01              0.5          True  0.347219     0.379496
# 10      0.01              1.0         False  0.348826     0.402980
# 11      0.01              1.0          True  0.322726     0.344288
# 12      0.10              0.0         False  0.379241     0.454675
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.lineplot(x="elasticNetParam", y="weighted F1", hue = "fitIntercept", data=lr, marker="o", ax=ax, ci=None)
fig.show()
plt.savefig("Tuning_LR_elasticNetParam-Fitintercept")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="elasticNetParam", y="weighted F1", hue = "fitIntercept", data=lr, ax=ax, ci=None)
fig.show()
plt.savefig("Tuning_LR_elasticNetParam-Fitintercept_barPlot")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.lineplot(x="regParam", y="f1", hue = "fitIntercept", data=lr, marker="o", ax=ax, ci=None)
fig.show()
plt.savefig("Tuning_LR_RegParam-Fitintercept")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="regParam", y="weighted F1", hue = "fitIntercept", data=lr, ax=ax, ci=None)
fig.show()
plt.savefig("Tuning_LR_RegParam-Fitintercept_bar")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.lineplot(x="regParam", y="f1", hue = "elasticNetParam", data=lr, marker="o", ax=ax, ci=None)
fig.show()
plt.savefig("Tuning_LR_RegParam-Netparam")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="regParam", y="weighted", hue = "elasticNetParam", data=lr,ax=ax, ci=None)
fig.show()
plt.savefig("Tuning_LR_RegParam-Netparam_bar")

# %%
df = pd.read_csv('nb_grid_search_results.csv', header=0)
nb = df
nb
# Out:
#     smoothing  accuracy  weighted F1
# 0        0.00  0.323831     0.309803
# 1        0.01  0.315599     0.292756
# 2        0.10  0.296527     0.265975
# 3        0.50  0.281570     0.246552
# 4        1.00  0.286087     0.254610
# 5       10.00  0.343405     0.344133
# 6      100.00  0.368300     0.431386
# 7      200.00  0.357559     0.436400
# 8      300.00  0.342301     0.425690
# 9      400.00  0.331259     0.415956
# 10     500.00  0.319916     0.405818
# 11    1000.00  0.288597     0.377887

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.lineplot(x="smoothing", y="weighted F1",data=nb, marker="o", ax=ax, ci=None)
fig.show()
plt.savefig("Tuning_NB")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[18,12])
sns.barplot(x="smoothing", y="weighted F1",data=nb, ax=ax, ci=None)
fig.show()
plt.savefig("Tuning_NB_bar")
